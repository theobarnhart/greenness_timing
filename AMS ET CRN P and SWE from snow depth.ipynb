# %% [markdown]
# # Notebook to examine relationships only between ET, P and Snowpack
#
# Discharge isnt really necessary if I make the assumption that $Q = P - ET$.
#
# I assume that AFX and Niwot SnoTel are close enough to be co-located.

# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import pylab
import matplotlib.pyplot as plt
import scipy as sp
import glob
import calendar
from mpl_toolkits.mplot3d import Axes3D
import statsmodels.api as sm
pylab.rcParams['figure.figsize'] = (22.0, 11.0)

# %% [markdown]
# ## Load AFX
# ### Header info
# - YEAR : year
# - GAP : unknown, maybe if a gap was present
# - DTIME : day of year (DOY) and decimal time
# - DOY : day of year
# - HRMIN
# - UST  [m/s]
# - TA [deg C] : air temperature
# - WD [deg] : wind direction
# - NEE [umol/m2/s] : Net Ecosystem Exchange
# - FC [umol/m2/s] : Carbon Flux
# - SFC [umol/m2/s]
# - H [W/m2]
# - SH [W/m2]
# - LE [W/m2]
# - SLE [W/m2]
# - FG [W/m2]
# - TS1 [deg C] : Soil temp 1
# - TSdepth1 [cm] : Depth of 1st soil temp.
# - TS2 [deg C] : Soil temp 2
# - TSdepth2 [cm] : Depth of 2nd soil temp.
# - PREC [mm] : precipitation
# - RH [%] : relative humidity
# - PRESS [kPa] : air pressure
# - VPD [umol/mol] : vapor pressure deficit
# - CO2 [kPa] : partial pressure of CO2
# - SWC1 [%] : soil moisture 1
# - SWC2 [%] : soil moisture 2
# - PAR [W/m2] : photosynthetically active radiation
# - Rn [umol/m2/s]  : net radiation
# - Rg [W/m2]
# - Rgdif [W/m2]
# - PARout [umol/m2/s]
# - RgOut [W/m2]
# - Rgl [W/m2]
# - RglOut [W/m2]
# - H2O [mmol/mol]
# - RE [umol/m2/s]
# - GPP [umol/m2/s]
# - CO2top [umol/mol]
# - CO2height [m]
# - APAR [umol/m2/s]
# - PARdif [umol/m2/s]
# - APARpct [%]
# - ZL [unitless]

# %%
afx = pd.read_pickle('./data/AFX_niwot.pcl')
#afx2 = pd.read_pickle('../../data/AFX_niwot_yearly.pcl')

# %%
plt.plot(afx.index, afx.ET, 'c', lw=2, alpha=0.5)
plt.plot(afx.resample('%W',how='mean').index, afx.resample('%W',how='mean').ET, 'k',lw = 3)
plt.title('AFX ET', fontsize=24)
plt.ylabel('Half-hour vapor flux [mm]', fontsize = 18);

# %%
axtickfont = 20
axlabelfont = 22
pylab.rcParams['figure.figsize'] = (22.0, 5.0)
plt.plot(afx['2009-10-01':'2012-09-30'].index, afx['2009-10-01':'2012-09-30'].SWC1,'c-', lw = 2);
plt.title('Niwot Ameriflux Soil Water Content', fontsize=axlabelfont+2);
plt.ylabel('[%]', fontsize = axlabelfont);
ax = plt.gca();
plt.setp(ax.get_xticklabels(), fontsize=axtickfont);
plt.setp(ax.get_yticklabels(), fontsize=axtickfont);
#plt.savefig('./figures/agu14_figs/AFX_SWC.pdf', bbox_inches = 'tight')
# Out:
# [None, None, None, None, None, None, None, None]

# %%
wyrs = [2010,2011,2012]
cols = ['Peak Soil Moisture','Ablation Slope','Partitioning']
tab = pd.DataFrame(np.zeros([len(wyrs),len(cols)]), index=wyrs, columns=cols)

for wy in wyrs:
    tab.loc[wy,'Peak Soil Moisture'] = afx[str(wy-1)+'-10-01':str(wy)+'-09-30'].SWC1.max()

# %%
tab
# Out:
#       Peak Soil Moisture  Ablation Slope  Partitioning
# 2010                33.0               0             0
# 2011                60.2               0             0
# 2012                21.7               0             0

# %% [markdown]
# ## Load Precip

# %%
wx = pd.read_pickle('./data/boulder_co.pcl')
wx = wx.sort()
wx.index.min()
# Out:
# Timestamp('2003-09-27 00:00:00')

# %%
## compute snow

maxthresh = 2. # maximum air temperature snow threshold
minthresh = 0. # threshold for 100% snow

for day in wx.index:
    
    # write NaNs to days without Data
    if np.isnan(wx.Tmax[day]) == 1:
        wx.loc[day,'snow'] = np.NaN
        continue
    if np.isnan(wx.Tmin[day]) == 1:
        wx.loc[day,'snow'] = np.NaN
        continue
        
    # if the max air temp does not rise above minthreshold then all the precip is snow.
    if wx.Tmax[day] <= minthresh:
        wx.loc[day,'snow'] = wx.P[day]
        
    # if the max air temp rises above maxthreshold then all the precip is rain
    if wx.Tmax[day] > maxthresh:
        wx.loc[day,'snow'] = 0.
    
    # if the max air is less or equal to maxthreshold and above minthresh then a portion of the precip is snow.
    if (wx.Tmax[day] <= maxthresh) and (wx.Tmax[day] > minthresh):
        # compute linear mixed snow coef based on max and min air temp. 
        coef = 1.-(1./(wx.Tmax[day] - wx.Tmin[day]))
        wx.loc[day,'snow'] = wx.P[day]*coef

# %%
wx.snow.describe()
# Out:
# count    3992.000000
# mean        1.219267
# std         3.949340
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max        72.100000
# Name: snow, dtype: float64

# %%
plt.bar(wx['2001-01-01':'2012-12-31'].index,wx['2001-01-01':'2012-12-31'].snow, facecolor = 'c', edgecolor = 'c')
plt.title('Niwot CRN Precip as snow', fontsize=24)
plt.ylabel('Precipitation [mm]', fontsize=18);

# %%
plt.bar(wx['2001-01-01':'2012-12-31'].index,wx['2001-01-01':'2012-12-31'].P, facecolor = 'c', edgecolor = 'c')
plt.title('Niwot CRN Precip', fontsize=24)
plt.ylabel('Precipitation [mm]', fontsize=18);

# %% [markdown]
# ## Load Snotel

# %%
niwot = pd.read_pickle('./data/niwot_snotel.pcl')

# %% [markdown]
# ## Load SWE Metrics

# %%
SWE = pd.read_pickle('./data/AMS_snowpack_metrics_mm.pcl')[:-2]

# %%
SWE # SWE in mm
# Out:
#          peakswe peakswedate snowfreedate  ablationrate  ablationseason  \
# 2006   47.582523  2006-04-08   2006-05-25      1.012394              47
# 2007  174.739295  2007-04-27   2007-06-14      3.640402              48
# 2008  132.440744  2008-05-12   2008-06-10      4.566922              29
# 2009  127.725831  2009-04-25   2009-06-05      3.115264              41
# 2010  126.274527  2010-05-16   2010-06-07      5.739751              22
# 2011  191.756482  2011-05-24   2011-06-24      6.185693              31
# 2012  107.611444  2012-04-20   2012-05-17      3.985609              27
#
#       growseasonlength  ablationseasonP      flux  ablationseasonRain  \
# 2006               175         2.059574  3.071969           46.341451
# 2007               156         2.097917  5.738319           61.749967
# 2008               141         3.317241  7.884164           65.668610
# 2009               158         2.675610  5.790874           91.091139
# 2010               137         0.190909  5.930660            3.653769
# 2011               129         1.790323  7.976016           54.377225
# 2012               163         1.711111  5.696720           19.642153
#
#       ablationseasonSnow  ablseas_total_P
# 2006           50.458549             96.8
# 2007           38.950033            100.7
# 2008           30.531390             96.2
# 2009           18.608861            109.7
# 2010            0.546231              4.2
# 2011            1.122775             55.5
# 2012           26.557847             46.2

# %% [markdown]
# # Extract Similar metrics for ET and P

# %% [markdown]
# ### P

# %%
wyears = SWE.index # grab the water years
print wyears

fall = range(10,13)
print 'Fall: '+str(fall)
winter = range(1,4)
print 'Winter: '+str(winter)
spring = range(4,7)
print 'Spring: '+str(spring)
summer = range(7,10)
print 'Summer: '+str(summer)

cool = range(10,13)+range(1,5)
print 'Cool: '+str(cool)
warm = range(5,10)
print 'Warm: '+str(warm)
# Out:
# Int64Index([2006, 2007, 2008, 2009, 2010, 2011, 2012], dtype='int64')
# Fall: [10, 11, 12]
# Winter: [1, 2, 3]
# Spring: [4, 5, 6]
# Summer: [7, 8, 9]
# Cool: [10, 11, 12, 1, 2, 3, 4]
# Warm: [5, 6, 7, 8, 9]

# %%
#cols = ['wyP','coolP','springP','summerP']
cols = ['wyP','snowFraction','coolP','warmP','springP','summerP','fallP','winterP']

P = pd.DataFrame(np.zeros([len(wyears),len(cols)]),index=wyears, columns=cols)

for year in wyears:
    P.loc[year, 'wyP'] = np.sum(wx.loc[str(year-1)+'-10-01':str(year)+'-09-30'].P)
    P.loc[year, 'snowFraction'] = np.sum(wx.loc[str(year-1)+'-10-01':str(year)+'-09-30'].snow)
    
    # Extract end dates for the seasons
    
    coolend = calendar.monthrange(year-1,cool[-1])[-1] 
    warmend = calendar.monthrange(year,warm[-1])[-1]
    
    fallend = calendar.monthrange(year-1,fall[-1])[-1]
    winterend = calendar.monthrange(year,winter[-1])[-1]
    springend = calendar.monthrange(year,spring[-1])[-1]
    summerend = calendar.monthrange(year,summer[-1])[-1]
    
    coolstartdate = str(year-1)+'-'+str(cool[0])+'-01'
    coolenddate = str(year)+'-'+str(cool[-1])+'-'+str(coolend)
    
    warmstartdate = str(year)+'-'+str(warm[0])+'-01'
    warmenddate = str(year)+'-'+str(warm[-1])+'-'+str(warmend)
    
    
    fallstartdate = str(year-1)+'-'+str(fall[0])+'-01'
    fallenddate = str(year-1)+'-'+str(fall[-1])+'-'+str(fallend)
    
    winterstartdate = str(year)+'-'+str(winter[0])+'-01'
    winterenddate = str(year)+'-'+str(winter[-1])+'-'+str(winterend)
    
    springstartdate = str(year)+'-'+str(spring[0])+'-01'
    springenddate = str(year)+'-'+str(spring[-1])+'-'+str(springend)
    
    summerstartdate = str(year)+'-'+str(summer[0])+'-01'
    summerenddate = str(year)+'-'+str(summer[-1])+'-'+str(summerend)
    
    
    P.loc[year, 'coolP'] = np.sum(wx.loc[coolstartdate:coolenddate].P)
    P.loc[year, 'warmP'] = np.sum(wx.loc[warmstartdate:warmenddate].P)
    
    P.loc[year, 'fallP'] = np.sum(wx.loc[fallstartdate:fallenddate].P)
    
    P.loc[year, 'winterP'] = np.sum(wx.loc[winterstartdate:winterenddate].P)
    
    P.loc[year, 'springP'] = np.sum(wx.loc[springstartdate:springenddate].P)
    
    P.loc[year, 'summerP'] = np.sum(wx.loc[summerstartdate:summerenddate].P)
    
    
P.snowFraction /= P.wyP

# %%
warm
# Out:
# [5, 6, 7, 8, 9]

# %%
coolend = calendar.monthrange(year-1,cool[-1])[-1]

# %%
coolend
# Out:
# 30

# %%
P.wyP - np.sum([P.coolP, P.warmP])
# Out:
# 2006   -4956.5
# 2007   -4885.6
# 2008   -4817.5
# 2009   -4884.8
# 2010   -4845.4
# 2011   -4618.0
# 2012   -4849.6
# Name: wyP, dtype: float64

# %%
P.wyP - np.sum([P.fallP, P.winterP, P.springP, P.summerP])
# Out:
# 2006   -4956.5
# 2007   -4885.6
# 2008   -4817.5
# 2009   -4884.8
# 2010   -4845.4
# 2011   -4618.0
# 2012   -4849.6
# Name: wyP, dtype: float64

# %%
P.wyP
# Out:
# 2006     686.4
# 2007     757.3
# 2008     825.4
# 2009     758.1
# 2010     797.5
# 2011    1024.9
# 2012     793.3
# Name: wyP, dtype: float64

# %% [markdown]
# ### ET

# %%
cols = ['wyET','growET','aveGrowET','wyNEE','growNEE','aveGrowNEE']

ET = pd.DataFrame(np.zeros([len(wyears),len(cols)]),index=wyears, columns=cols)

for year in wyears:
    ET.loc[year,'wyET'] = np.sum(afx.loc[str(year-1)+'-10-01':str(year)+'-09-30'].tot_ET) # compute water year ET
    
    strt = SWE.ix[year].peakswedate
    
    ET.loc[year,'growET'] = np.sum(afx.loc[str(strt.year)+'-'+str(strt.month)+'-'+str(strt.day):str(year)+'-09-30'].tot_ET)
    
    ET.loc[year,'aveGrowET'] = ET.loc[year,'growET']/SWE.loc[year,'growseasonlength']
    
    ET.loc[year,'wyNEE'] = np.sum(afx.loc[str(year-1)+'-10-01':str(year)+'-09-30'].tot_NEE)
    
    ET.loc[year,'growNEE'] = np.sum(afx.loc[str(strt.year)+'-'+str(strt.month)+'-'+str(strt.day):str(year)+'-09-30'].tot_NEE)
    
    ET.loc[year,'aveGrowNEE'] = ET.loc[year,'growNEE']/SWE.loc[year,'growseasonlength']

# %%
SWE.loc[year,'growseasonlength']
# Out:
# 163.0

# %%
ET
# Out:
#             wyET      growET  aveGrowET       wyNEE     growNEE     aveGrowNEE
# 2006  618.061701  369.313047   2.110360 -22897312.2 -26740899.0 -152805.137143
# 2007  630.939326  367.622453   2.356554 -19104467.4 -25268923.8 -161980.280769
# 2008  641.237630  339.699444   2.409216 -21152133.0 -25182410.4 -178598.655319
# 2009  609.334106  363.156291   2.298458 -23197210.2 -26194255.2 -165786.425316
# 2010  592.750001  329.382040   2.404248 -17791702.2 -23041157.4 -168183.630657
# 2011  648.274141  347.027020   2.690132 -22636204.2 -25823730.6 -200183.958140
# 2012  640.542938  393.084223   2.411560 -21468756.6 -25663699.8 -157446.011043

# %% [markdown]
# ### Derived Metrics

# %%
cols = ['wyPartitioning','growPartitioning','peakSWEFrac', 'wyGrowPartitioningSWE']

MET = pd.DataFrame(np.zeros([len(wyears),len(cols)]),index=wyears, columns=cols)

for year in wyears:
    MET.loc[year,'wyPartitioning'] = ET.loc[year,'wyET'] / P.loc[year,'wyP']
    MET.loc[year,'growPartitioning'] = ET.loc[year,'growET'] / P.loc[year,'wyP']
    MET.loc[year,'peakSWEFrac'] = SWE.loc[year,'peakswe']/ P.loc[year,'wyP']
    MET.loc[year,'wyGrowPartitioningSWE'] = ET.loc[year,'growET']/ SWE.loc[year,'peakswe']

# %%
MET
# Out:
#       wyPartitioning  growPartitioning  peakSWEFrac  wyGrowPartitioningSWE
# 2006        0.900440          0.538043     0.069322               7.761527
# 2007        0.833143          0.485438     0.230740               2.103834
# 2008        0.776881          0.411557     0.160456               2.564916
# 2009        0.803765          0.479035     0.168482               2.843249
# 2010        0.743260          0.413018     0.158338               2.608460
# 2011        0.632524          0.338596     0.187098               1.809728
# 2012        0.807441          0.495505     0.135650               3.652811

# %% [markdown]
# ## Fill in the example table

# %%
wyrs =[2010,2011,2012]
for wy in wyrs:
    tab.loc[wy,'Partitioning'] = MET.loc[wy,'growPartitioning']
    tab.loc[wy,'Ablation Slope'] = SWE.loc[wy,'ablationrate']

# %%
tab
# Out:
#       Peak Soil Moisture  Ablation Slope  Partitioning
# 2010                33.0        5.739751      0.413018
# 2011                60.2        6.185693      0.338596
# 2012                21.7        3.985609      0.495505

# %% [markdown]
# # Plots

# %%
from scipy import stats

def linpred(slope,intercept,xvals):
    yvals = (xvals*slope)+intercept
    return yvals

# %% [markdown]
# **Figure 1:** Water year precipitation partitiong versus ablation slope. Aside from 2008(?) more water is partitioned to ET with slower ablation.

# %%
# Plotting parameters for poster figs

titlefont = 40
axfont = 24
axtickfont = 22

legendfontsize = 30

pointsize = 550

eqtext = 20

# turn on if you want to output figures
printfigs = False
pylab.rcParams['figure.figsize'] = (22.0, 11.0)

annotatey = [0.85,0.82,0.79,0.76,0.72,0.69,0.66,0.63]

# %%
# load the VIC data

vicswe = pd.read_pickle('../Budyko_vic/data/AFX_cell.df')

# %%
fig = plt.figure(figsize=(12.0, 8.0))
printfigs = True
wyrs = ['06','07','08','09','10','11','12']

annotatey = [0.95,0.91,0.87,0.83,0.79,0.75,0.71]

ttl = 'Como Creek, CO'
x = SWE.flux
xlab = 'Water Flux [mm/d]'
y = MET.growPartitioning
ylab = 'ET/P [1]'
annotatex = 10
out = '/Users/barnhatb/Dropbox/CUB/05_Spring_2015/WSC PI meeting/figures/water_flux_partitioning.pdf'
pointsize = 250

#######################################
x3 = x
y3 = y

slope, intercept, r_value, p_value, std_err = stats.linregress(x,y)
yvals = linpred(slope, intercept, x)


ax = fig.add_subplot(111)
ax.scatter(x, y, pointsize, c = 'k', edgecolor='none')


ax.set_ylabel(ylab, fontsize = axfont)
ax.set_xlabel(xlab, fontsize = axfont)
ax.plot(x, yvals, 'r-', lw = 2)

plt.setp(ax.get_xticklabels(), fontsize=axtickfont)
plt.setp(ax.get_yticklabels(), fontsize=axtickfont)

EQ = 'y = '+str(round(slope,3))+'x + '+str(round(intercept,3))

ax.text(annotatex,annotatey[0],'**Observed Data**', fontsize = eqtext)
ax.text(annotatex,annotatey[1],EQ, fontsize = eqtext)
ax.text(annotatex,annotatey[2],'r$^2$='+str(round(r_value**2,3))+', p=' + str(round(p_value,3)), fontsize = eqtext)
ax.text(annotatex-1,annotatey[6], 'ANOVA(VIC,OBS): p=0.050', fontsize=eqtext)

#for x2, y2, wyrs in zip(x3, y3, wyrs):
#    # Annotate the points 5 _points_ above and to the left of the vertex
#    ax.annotate('{}'.format(wyrs), xy=(x2,y2), xytext=(15,17), ha='left',
#                textcoords='offset points', fontsize=20)
 
    
x = vicswe.flux.dropna()
y = vicswe.gsET_P.dropna()

ax.scatter(x, y, pointsize, c = '0.5', edgecolor='none')

slope, intercept, r_value, p_value, std_err = stats.linregress(x,y)
yvals = linpred(slope, intercept, x)

ax.plot(x, yvals, 'g-', lw = 2)

EQ = 'y = '+str(round(slope,3))+'x + '+str(round(intercept,3))

plt.text(annotatex,annotatey[3],'**VIC Data**', fontsize = eqtext)
plt.text(annotatex,annotatey[4],EQ, fontsize = eqtext)
plt.text(annotatex,annotatey[5],'r$^2$='+str(round(r_value**2,3))+', p=' + str(round(p_value,3)), fontsize = eqtext)

ax.legend(['Observed Model','VIC Model','Observed Data','VIC data'], loc = 'lower right', fontsize = eqtext)

#printfigsq=True
#if printfigs == True:
#    plt.savefig(out,transparent = True, bbox_inches = 'tight')
plt.savefig('./figures/como_wflux_wyET_P_VIC_wsnow.pdf',bbox_in='tight',background='transparent')

# %%
yvals
# Out:
# 1951    0.6410669
# 1952    0.5702029
# 1953    0.7116863
# 1954    0.8109574
# 1955    0.7802652
# 1956     0.753032
# 1957    0.5038214
# 1958    0.6830369
# 1959    0.6468229
# 1960    0.7450669
# 1961     0.666375
# 1962    0.6763612
# 1963    0.7965311
# 1964    0.7594132
# 1965    0.6247994
# ...
# 1999    0.7679266
# 2000    0.6911848
# 2001    0.6320213
# 2002    0.7892056
# 2003    0.6449779
# 2004    0.7616667
# 2005    0.6963382
# 2006    0.7671044
# 2007    0.7331063
# 2008    0.6567612
# 2009    0.6933711
# 2010    0.7435408
# 2011    0.6842904
# 2012    0.7893688
# 2013    0.6507544
# Name: flux, Length: 62, dtype: object

# %%
res2 = sm.load('../Budyko_vic/models/niwot_vic_gsET_PvsFlux.mod')

# %%
X = SWE.flux.astype(float)
y = MET.growPartitioning.astype(float)

X = sm.add_constant(X)

results = sm.OLS(y,X).fit()

# %%
sm.stats.anova_lm(res2,results, typ=1, robust='hc3')
# Out:
#    df_resid       ssr  df_diff   ss_diff         F    Pr(>F)
# 0        60  0.331615        0       NaN       NaN       NaN
# 1         5  0.006648       55  0.324968  4.443874  0.049846

# %%
np.var(y)
# Out:
# 0.0038799590090347535

# %%
0.01166/0.00387996
# Out:
# 3.0051856204703142

# %%
res2.model.data.
# Out:
#   File "<ipython-input-41-4298c8539dfd>", line 1
#     res2.model.data.
#                     ^
# SyntaxError: invalid syntax

# %%
X = pd.DataFrame({'abl':SWE.ablationrate,'p':P.wyP}) # standardize the variables
X = sm.add_constant(X)
y = MET.growPartitioning # standardized
m1 = sm.OLS(y,X)
f1 = m1.fit()

EQ = 'y = '+str(round(f1.params[1],3))+'x1 + '+str(round(f1.params[2],3))+'x2 '+str(round(f1.params[0],3))

xx1, xx2 = np.meshgrid(np.linspace(X.abl.min(), X.abl.max(), 100), 
                       np.linspace(X.p.min(), X.p.max(), 100))
Z = f1.params[0] + f1.params[1] * xx1 + f1.params[2] * xx2

# %%
fig = plt.figure(figsize=[30,15])
ax = fig.add_subplot(111,projection = '3d')
# y,x,z
l = ax.plot_surface(xx1,xx2,Z,alpha=0.3,linewidth=0, color='m')
#cmap = plt.cm.seismic
p = ax.scatter(SWE.ablationrate,P.wyP,MET.growPartitioning, zdir = 'z', s = 200, c = 'k')
resid = y - f1.predict(X)
# data points over the plane are white, below are black
#ax.scatter(X[resid >= 0].abl, X[resid >= 0].p, y[resid >= 0], color='black', alpha=1.0, facecolor='white', s = 150)
#ax.scatter(X[resid < 0].abl, X[resid < 0].p, y[resid < 0], color='black', alpha=1.0, s = 150)

#plt.text(0.1,0.6,EQ)
#plt.text(0.1,0.55,'r$^2$: '+str(round(f1.rsquared,3)))
#plt.text(0.1,0.5,'pValue: ' + str(round(f1.pvalues,3)))

print EQ
print'R$^2$:',f1.rsquared
print'Pvalue:',f1.pvalues[0]

labsize = 28
axfotn = 20

ax.set_xlabel('Ablation Rate [cm/d]', fontsize = labsize)
ax.set_ylabel('Precipitation [mm]', fontsize = labsize)
ax.set_zlabel('ET/P', fontsize = labsize)
plt.setp(ax.get_ymajorticklabels(),fontsize=axfont)
plt.setp(ax.get_xmajorticklabels(),fontsize=axfont)
plt.setp(ax.get_zmajorticklabels(),fontsize=axfont)

plt.title('Como Creek, CO', fontsize=32)
#plt.savefig('./figures/agu14_figs/como_multiple_regression.pdf',bbox_inches='tight',transparent=True)

# %%
f1.params

# %%
fig = plt.figure(figsize=[30,7])
ax = plt.gca()
lns1 = ax.plot(afx.resample('2W',how='mean').index, afx.resample('2W',how='mean').tot_ET, 'c',lw = 4, label='ET')
ax2 = ax.twinx()
lns2 = ax2.plot(niwot.index, niwot.swe, lw = 3,label = 'SWE')
ax2.set_ylim([0,25])
ax.set_ylim([0,.1])
ax.set_ylabel('ET [mm/m$^2$ $\cdot$ 30 min]', fontsize = 34)
ax2.set_ylabel('SWE [cm]', fontsize=34)

plt.setp(ax.get_ymajorticklabels(),fontsize=30)
plt.setp(ax2.get_ymajorticklabels(),fontsize=30)
plt.setp(ax.get_xmajorticklabels(), fontsize=30)
plt.setp(ax2.get_xmajorticklabels(), fontsize=30)

plt.title('Como Creek, CO', fontsize = 40 )

lns = lns1+lns2
labs = [l.get_label() for l in lns];
ax.legend(lns, labs, loc='upper left', fontsize=30);


plt.xlim(['2005-10-01','2012-09-30']);
#plt.savefig('./figures/agu14_figs/Como_ET_SWE_timeseries.pdf',bbox_inches='tight',transparent=True)

# %%
## For Adrian's CUAHSI Talk
fig = plt.figure(figsize=[30,10])
ax = plt.gca()
lns1 = ax.plot(afx.resample('2W',how='mean').index, afx.resample('2W',how='mean').tot_ET, 'c',lw = 6, label='ET')
ax2 = ax.twinx()
lns2 = ax2.plot(niwot.index, niwot.swe, lw = 6,label = 'SWE')
ax2.set_ylim([0,25])
ax.set_ylim([0,.1])
ax.set_ylabel('ET [mm/m$^2$ $\cdot$ 30 min]', fontsize = 35)
ax2.set_ylabel('SWE [cm]', fontsize=35)

plt.setp(ax.get_ymajorticklabels(),fontsize=35)
plt.setp(ax2.get_ymajorticklabels(),fontsize=35)
plt.setp(ax.get_xmajorticklabels(), fontsize=32)
plt.setp(ax2.get_xmajorticklabels(), fontsize=32)

plt.title('Como Creek, CO', fontsize = 40 )

lns = lns1+lns2
labs = [l.get_label() for l in lns];
ax.legend(lns, labs, loc='upper left', fontsize=35);


plt.xlim(['2009-10-01','2012-09-30']);
#plt.savefig('./figures/agu14_figs/Como_ET_SWE_timeseries.pdf',bbox_inches='tight',transparent=True)

plt.savefig('./figures/como_SWE_ET_for_AAH.pdf', bbox_inches='tight',transparent=True)

# %%
fig = plt.figure(figsize=[30,7])
ax = plt.gca()
lns1 = ax.plot(afx.resample('2W',how='mean').index, afx.resample('2W',how='mean').tot_NEE, 'g',lw = 4, label='NEE')
ax2 = ax.twinx()
lns2 = ax2.plot(niwot.index, niwot.swe, lw = 3,label = 'SWE')
ax2.set_ylim([0,25])
ax.set_ylim([-15000,5000])
ax.set_ylabel('NEE [$\mu$mol C/m$^2$ $\cdot$ 30 min]', fontsize = 34)
ax2.set_ylabel('SWE [cm]', fontsize=34)

plt.setp(ax.get_ymajorticklabels(),fontsize=30)
plt.setp(ax2.get_ymajorticklabels(),fontsize=30)
plt.setp(ax.get_xmajorticklabels(), fontsize=30)
plt.setp(ax2.get_xmajorticklabels(), fontsize=30)

plt.title('Como Creek, CO', fontsize = 40 )

lns = lns1+lns2
labs = [l.get_label() for l in lns];
ax.legend(lns, labs, loc='upper left', fontsize=30);
ax.invert_yaxis()

plt.xlim(['2005-10-01','2012-09-30']);
plt.savefig('./figures/agu14_figs/Como_NEE_SWE_timeseries.pdf',bbox_inches='tight',transparent=True)

# %%
pylab.rcParams['figure.figsize'] = (22.0, 11.0)
printfigs = False
wyrs = ['06','07','08','09','10','11','12']
annotatey = [0.4,0.35,0.3,0.51,0.46,0.43,0.4]

ttl = 'wyP vs Ablation Slope'
x = P.wyP
xlab = 'Precipitation [mm]'

y = SWE.ablationrate
ylab = 'Ablation Slope [cm/d]'
annotatex = 900.
out = './figures/agu14_figs/wyP_vs_AblationSlp_CRN.pdf'


#######################################
x3 = x
y3 = y

slope, intercept, r_value, p_value, std_err = stats.linregress(x,y)
yvals = linpred(slope, intercept, x)


plt.scatter(x, y, pointsize, c = 'k', edgecolor='none')
ax = plt.gca()


#cb = plt.colorbar()
#cb.set_label('Water Year', fontsize = axfont)

plt.title(ttl, fontsize = titlefont)
plt.ylabel(ylab, fontsize = axfont)
plt.xlabel(xlab, fontsize = axfont)
plt.plot(x, yvals, 'r-', lw = 2)

plt.setp(ax.get_xticklabels(), fontsize=axtickfont)
plt.setp(ax.get_yticklabels(), fontsize=axtickfont)
#cb.ax.tick_params(labelsize=axtickfont) 

#plt.legend(['All data'],'lower left', fontsize = legendfontsize)

EQ = 'y = '+str(round(slope,3))+'x + '+str(round(intercept,3))

#plt.text(annotatex,annotatey[0],'**All Data:**', fontsize = eqtext)
plt.text(annotatex,annotatey[0],EQ, fontsize = eqtext)
plt.text(annotatex,annotatey[1],'r$^2$: '+str(round(r_value**2,3)), fontsize = eqtext)
plt.text(annotatex,annotatey[2],'pValue: ' + str(round(p_value,3)), fontsize = eqtext)

for x2, y2, wyrs in zip(x3, y3, wyrs):
    # Annotate the points 5 _points_ above and to the left of the vertex
    ax.annotate('{}'.format(wyrs), xy=(x2,y2), xytext=(-17,17), ha='left',
                textcoords='offset points', fontsize=25)
    

#plt.text(.5,0.83,'A', fontsize = eqtext+30);
    
#plt.text(x,y,wyrs);
#plt.show

if printfigs == True:
    plt.savefig(out,transparent = True, bbox_inches = 'tight')

# %%
# save the residuals

SWE['ablP_resid'] = SWE.ablationrate-yvals

# %%
SWE.ablP_resid
# Out:
# 2006    -0.1440465
# 2007    0.02505543
# 2008    0.02770902
# 2009    -0.0285156
# 2010     0.1818635
# 2011    -0.0740657
# 2012    0.01199987
# Name: ablP_resid, dtype: object

# %%
pylab.rcParams['figure.figsize'] = (22.0, 11.0)
printfigs = False
wyrs = ['06','07','08','09','10','11','12']
annotatey = [0.57,0.55,0.53,0.51,0.46,0.43,0.4]

ttl = 'Growing Season Partitioning vs Ablation Slope'
x = SWE.ablP_resid
xlab = 'Ablation Slope - P Residual'
y = MET.growPartitioning
ylab = 'ET/P [1]'
annotatex = .45
out = './figures/agu14_figs/gsET_vs_AblationSlp_CRN.pdf'


#######################################
x3 = x
y3 = y

slope, intercept, r_value, p_value, std_err = stats.linregress(x,y)
yvals = linpred(slope, intercept, x)


plt.scatter(x, y, pointsize, c = 'k', edgecolor='none')
ax = plt.gca()


#cb = plt.colorbar()
#cb.set_label('Water Year', fontsize = axfont)

plt.title(ttl, fontsize = titlefont)
plt.ylabel(ylab, fontsize = axfont)
plt.xlabel(xlab, fontsize = axfont)
plt.plot(x, yvals, 'r-', lw = 2)

plt.setp(ax.get_xticklabels(), fontsize=axtickfont)
plt.setp(ax.get_yticklabels(), fontsize=axtickfont)
#cb.ax.tick_params(labelsize=axtickfont) 

#plt.legend(['All data'],'lower left', fontsize = legendfontsize)

EQ = 'y = '+str(round(slope,3))+'x + '+str(round(intercept,3))

#plt.text(annotatex,annotatey[0],'**All Data:**', fontsize = eqtext)
plt.text(annotatex,annotatey[0],EQ, fontsize = eqtext)
plt.text(annotatex,annotatey[1],'r$^2$: '+str(round(r_value**2,3)), fontsize = eqtext)
plt.text(annotatex,annotatey[2],'pValue: ' + str(round(p_value,3)), fontsize = eqtext)

for x2, y2, wyrs in zip(x3, y3, wyrs):
    # Annotate the points 5 _points_ above and to the left of the vertex
    ax.annotate('{}'.format(wyrs), xy=(x2,y2), xytext=(-17,17), ha='left',
                textcoords='offset points', fontsize=25)
    

#plt.text(.5,0.83,'A', fontsize = eqtext+30);
    
#plt.text(x,y,wyrs);
#plt.show

if printfigs == True:
    plt.savefig(out,transparent = True, bbox_inches = 'tight')

# %%
pylab.rcParams['figure.figsize'] = (22.0, 11.0)
printfigs = False
wyrs = ['06','07','08','09','10','11','12']
annotatey = [0.57,0.55,0.53,0.51,0.46,0.43,0.4]

ttl = 'Growing Season NEE vs Ablation Slope'
x = SWE.ablationrate
xlab = 'Ablation Slope [cm/d]'
y = ET.growNEE
ylab = 'NEE [mm mol]'
annotatex = .45
out = './figures/agu14_figs/gsNEE_vs_AblationSlp_CRN.pdf'


#######################################
x3 = x
y3 = y

slope, intercept, r_value, p_value, std_err = stats.linregress(x,y)
yvals = linpred(slope, intercept, x)


plt.scatter(x, y, pointsize, c = 'k', edgecolor='none')
ax = plt.gca()

plt.title(ttl, fontsize = titlefont)
plt.ylabel(ylab, fontsize = axfont)
plt.xlabel(xlab, fontsize = axfont)
plt.plot(x, yvals, 'r-', lw = 2)

plt.setp(ax.get_xticklabels(), fontsize=axtickfont)
plt.setp(ax.get_yticklabels(), fontsize=axtickfont)

EQ = 'y = '+str(round(slope,3))+'x + '+str(round(intercept,3))

#plt.text(annotatex,annotatey[0],EQ, fontsize = eqtext)
#plt.text(annotatex,annotatey[1],'r$^2$: '+str(round(r_value**2,3)), fontsize = eqtext)
#plt.text(annotatex,annotatey[2],'pValue: ' + str(round(p_value,3)), fontsize = eqtext)

print EQ
print 'r$^2$: '+str(round(r_value**2,3))
print 'pValue: ' + str(round(p_value,3))


for x2, y2, wyrs in zip(x3, y3, wyrs):
    # Annotate the points 5 _points_ above and to the left of the vertex
    ax.annotate('{}'.format(wyrs), xy=(x2,y2), xytext=(-17,17), ha='left',
                textcoords='offset points', fontsize=25)
    
if printfigs == True:
    plt.savefig(out,transparent = True, bbox_inches = 'tight')
# Out:
# y = 4439201.146x + -27207722.802
# r$^2$: 0.426
# pValue: 0.112

# %%
pylab.rcParams['figure.figsize'] = (22.0, 11.0)
printfigs = False
wyrs = ['06','07','08','09','10','11','12']
annotatey = [-180000.,-185000.,-190000.,0.51,0.46,0.43,0.4]

ttl = 'Averge Growing Season NEE vs Ablation Slope'
x = SWE.ablationrate
xlab = 'Ablation Slope [cm/d]'
y = ET.aveGrowNEE
ylab = 'NEE [mm mol C/day]'
annotatex = .05
out = './figures/agu14_figs/aveGrowNEE_vs_AblSlope_CRN.pdf'


#######################################
x3 = x
y3 = y

slope, intercept, r_value, p_value, std_err = stats.linregress(x,y)
yvals = linpred(slope, intercept, x)


plt.scatter(x, y, pointsize, c = 'k', edgecolor='none')
ax = plt.gca()

plt.title(ttl, fontsize = titlefont)
plt.ylabel(ylab, fontsize = axfont)
plt.xlabel(xlab, fontsize = axfont)
plt.plot(x, yvals, 'r-', lw = 2)

plt.setp(ax.get_xticklabels(), fontsize=axtickfont)
plt.setp(ax.get_yticklabels(), fontsize=axtickfont)

EQ = 'y = '+str(round(slope,3))+'x + '+str(round(intercept,3))

plt.text(annotatex,annotatey[0],EQ, fontsize = eqtext)
plt.text(annotatex,annotatey[1],'r$^2$: '+str(round(r_value**2,3)), fontsize = eqtext)
plt.text(annotatex,annotatey[2],'pValue: ' + str(round(p_value,3)), fontsize = eqtext)

print EQ
print 'r$^2$: '+str(round(r_value**2,3))
print 'pValue: ' + str(round(p_value,3))


for x2, y2, wyrs in zip(x3, y3, wyrs):
    # Annotate the points 5 _points_ above and to the left of the vertex
    ax.annotate('{}'.format(wyrs), xy=(x2,y2), xytext=(-17,17), ha='left',
                textcoords='offset points', fontsize=25)
    
if printfigs == True:
    plt.savefig(out,transparent = True, bbox_inches = 'tight')
    printfigs = False
# Out:
# y = -70191.69x + -140960.057
# r$^2$: 0.582
# pValue: 0.046

# %%
labfont = 30
titfont = 36
tickfont = 28
lw = 4
legfont = 30

plt.figure(figsize=[22,11]);
ax = plt.gca();
ax2 = ax.twinx();

lns1 = ax.plot(ET.index, ET.aveGrowNEE,'g-',lw=lw, label = 'Average NEE');
ax.set_ylabel('Average Growing Season NEE [mm mol C/day]', fontsize = labfont);

lns2 = ax2.plot(SWE.index, SWE.ablationrate,'b-',lw=lw,label = 'Ablation Slope');
ax2.set_ylabel('Ablation Slope [cm/d]', fontsize = labfont);

lns = lns1+lns2
labs = [l.get_label() for l in lns];
ax.legend(lns, labs, loc='lower right', fontsize=legfont);
plt.xlim([2005,2013]);
ax.set_ylim([-220000,-150000])
ax2.set_ylim([0.1,0.9])
ax2.invert_yaxis()
plt.title('Growing Season NEE and Ablation Slope', fontsize=titfont);
ax.set_xticklabels(['2005','2006','2007','2008','2009','2010','2011','2012','2013'], fontsize=tickfont);
plt.setp(ax.get_yticklabels(), fontsize=tickfont);
plt.setp(ax2.get_yticklabels(), fontsize=tickfont);

#plt.savefig('./figures/agu14_figs/Como_gsNEEvsAblSLP_TS.pdf',transparent = True, bbox_inches='tight')
# Out:
# [None, None, None, None, None, None, None, None, None, None]

# %%
X = pd.DataFrame({'abl':SWE.ablationrate/SWE.ablationrate.mean(),'p':P.wyP/P.wyP.mean()}) # standardize the variables

# %%
X['PxAS'] = X.abl*X.p

# %%
X = sm.add_constant(X)

# %%
y = MET.growPartitioning/MET.growPartitioning.mean() # standardized

# %%
m1 = sm.OLS(y,X)

# %%
est = m1.fit()

# %%
print est.summary()
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:       growPartitioning   R-squared:                       0.921
# Model:                            OLS   Adj. R-squared:                  0.843
# Method:                 Least Squares   F-statistic:                     11.71
# Date:                Fri, 05 Dec 2014   Prob (F-statistic):             0.0366
# Time:                        16:34:04   Log-Likelihood:                 12.833
# No. Observations:                   7   AIC:                            -17.67
# Df Residuals:                       3   BIC:                            -17.88
# Df Model:                           3
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# const          1.0835      1.161      0.933      0.420        -2.612     4.779
# abl            0.2072      0.641      0.323      0.768        -1.833     2.247
# p              0.1860      1.343      0.138      0.899        -4.089     4.461
# PxAS          -0.4587      0.774     -0.593      0.595        -2.922     2.005
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   1.352
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.050
# Skew:                           0.203   Prob(JB):                        0.975
# Kurtosis:                       2.912   Cond. No.                         189.
# ==============================================================================

# %%
X = pd.DataFrame({'abl':SWE.ablationrate/SWE.ablationrate.mean(),'p':P.wyP/P.wyP.mean()}) # standardize the variables
X = sm.add_constant(X)
y = MET.growPartitioning/MET.growPartitioning.mean() # standardized
m2 = sm.OLS(y,X)

# %%
import statsmodels.stats.anova as anova
table1 = anova.anova_lm(m2.fit(), m1.fit())

print table1
# Out:
#    df_resid       ssr  df_diff   ss_diff         F    Pr(>F)
# 0         4  0.011703        0       NaN       NaN       NaN
# 1         3  0.010476        1  0.001226  0.351163  0.595155

# %%
anova.anova_lm()

# %%
SSE_whole = est.ssr # grab for the partial r2 calculation 
R2_whole = est.rsquared

# %%
X = pd.DataFrame({'abl':SWE.ablationrate/SWE.ablationrate.mean()}) # standardize the variables
X = sm.add_constant(X)
m3 = sm.OLS(y,X)
est = m2.fit()

SSE_woP = est.ssr
print est.summary()
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:       growPartitioning   R-squared:                       0.912
# Model:                            OLS   Adj. R-squared:                  0.868
# Method:                 Least Squares   F-statistic:                     20.76
# Date:                Fri, 05 Dec 2014   Prob (F-statistic):            0.00772
# Time:                        16:50:27   Log-Likelihood:                 12.446
# No. Observations:                   7   AIC:                            -18.89
# Df Residuals:                       4   BIC:                            -19.05
# Df Model:                           2
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# const          1.7565      0.222      7.905      0.001         1.140     2.373
# abl           -0.1683      0.088     -1.915      0.128        -0.412     0.076
# p             -0.5882      0.286     -2.054      0.109        -1.383     0.207
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   1.472
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                1.175
# Skew:                           0.999   Prob(JB):                        0.556
# Kurtosis:                       3.192   Cond. No.                         31.4
# ==============================================================================

# %%
X = pd.DataFrame({'p':P.wyP/P.wyP.mean()}) # standardize the variables
X = sm.add_constant(X)
m4 = sm.OLS(y,X)
est = m3.fit()
SSE_woAbl = est.ssr
print est.summary()
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:       growPartitioning   R-squared:                       0.819
# Model:                            OLS   Adj. R-squared:                  0.783
# Method:                 Least Squares   F-statistic:                     22.70
# Date:                Fri, 05 Dec 2014   Prob (F-statistic):            0.00504
# Time:                        16:50:28   Log-Likelihood:                 9.9259
# No. Observations:                   7   AIC:                            -15.85
# Df Residuals:                       5   BIC:                            -15.96
# Df Model:                           1
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# const          1.3146      0.071     18.503      0.000         1.132     1.497
# abl           -0.3146      0.066     -4.764      0.005        -0.484    -0.145
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   2.859
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.532
# Skew:                           0.178   Prob(JB):                        0.766
# Kurtosis:                       1.697   Cond. No.                         5.25
# ==============================================================================

# %%
anova_lm(m4.fit(),m2.fit())
# Out:
#    df_resid       ssr  df_diff  ss_diff         F    Pr(>F)
# 0         5  0.022432        0      NaN       NaN       NaN
# 1         4  0.011703        1  0.01073  3.667422  0.127999

# %%
print m2.fit().summary()
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:       growPartitioning   R-squared:                       0.912
# Model:                            OLS   Adj. R-squared:                  0.868
# Method:                 Least Squares   F-statistic:                     20.76
# Date:                Fri, 05 Dec 2014   Prob (F-statistic):            0.00772
# Time:                        17:01:16   Log-Likelihood:                 12.446
# No. Observations:                   7   AIC:                            -18.89
# Df Residuals:                       4   BIC:                            -19.05
# Df Model:                           2
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# const          1.7565      0.222      7.905      0.001         1.140     2.373
# abl           -0.1683      0.088     -1.915      0.128        -0.412     0.076
# p             -0.5882      0.286     -2.054      0.109        -1.383     0.207
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   1.472
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                1.175
# Skew:                           0.999   Prob(JB):                        0.556
# Kurtosis:                       3.192   Cond. No.                         31.4
# ==============================================================================

# %%
def cpd(SSE_x1,SSE_x1x2):
    return (SSE_x1-SSE_x1x2)/SSE_x1

# %%
# calculate partial R2

print 'R$^2_{whole}$: '+str(R2_whole)
print 'R$^2_{ablation slope}$: '+str(cpd(SSE_woAbl,SSE_whole))
print 'R$^2_{WY precip.}$: '+str(cpd(SSE_woP,SSE_whole))
# Out:
# R$^2_{whole}$: 0.912125133395
# R$^2_{ablation slope}$: 0.478312283768
# R$^2_{WY precip.}$: 0.513251880058

# %%
SSE_whole
# Out:
# 0.011702639310739317

# %%
whos
# Out:
# Variable          Type                        Data/Info
# -------------------------------------------------------
# EQ                str                         y = -70191.69x + -140960.057
# ET                DataFrame                               wyET      gro<...>25663699.8 -157446.011043
# MET               DataFrame                         wyPartitioning  gro<...>65              36.528106
# P                 DataFrame                            wyP  snowFractio<...>    311.4  174.9    173.2
# SSE_whole         float64                     0.0117026393107
# SSE_woAbl         float64                     0.022432269242
# SSE_woP           float64                     0.0240424951454
# SWE               DataFrame                          peakswe          p<...>        163  0.01199987
# X                 DataFrame                         const         p\n20<...>85\n2012      1  0.984086
# afx               DataFrame                                        YEAR<...>210384 rows x 49 columns]
# annotatex         float                       0.05
# annotatey         list                        n=7
# ax                AxesSubplot                 Axes(0.125,0.125;0.775x0.775)
# ax2               AxesSubplot                 Axes(0.125,0.125;0.775x0.775)
# axfont            int                         30
# axlabelfont       int                         22
# axtickfont        int                         26
# calendar          module                      <module 'calendar' from '<...>/python2.7/calendar.pyc'>
# coef              float64                     0.885057471264
# cols              list                        n=4
# cool              list                        n=7
# coolend           int                         30
# coolenddate       str                         2012-4-30
# coolstartdate     str                         2011-10-01
# day               Timestamp                   2014-10-09 00:00:00
# eqtext            int                         30
# est               RegressionResultsWrapper    <statsmodels.regression.l<...>er object at 0x11055aa90>
# fall              list                        n=3
# fallend           int                         31
# fallenddate       str                         2011-12-31
# fallstartdate     str                         2011-10-01
# glob              module                      <module 'glob' from '/Use<...>/lib/python2.7/glob.pyc'>
# intercept         float64                     -140960.057034
# l                 Line2D                      Line2D(Ablation Slope)
# labfont           int                         30
# labs              list                        n=2
# legendfontsize    int                         30
# legfont           int                         30
# linpred           function                    <function linpred at 0x1105da848>
# lns               list                        n=2
# lns1              list                        n=1
# lns2              list                        n=1
# lw                int                         4
# m1                OLS                         <statsmodels.regression.l<...>LS object at 0x11055a490>
# m2                OLS                         <statsmodels.regression.l<...>LS object at 0x1291ef7d0>
# m3                OLS                         <statsmodels.regression.l<...>LS object at 0x10fe4d990>
# maxthresh         float                       2.0
# minthresh         float                       0.0
# out               str                         ./figures/agu14_figs/aveG<...>owNEE_vs_AblSlope_CRN.pdf
# p_value           float64                     0.046070361678
# pd                module                      <module 'pandas' from '/U<...>ges/pandas/__init__.pyc'>
# pointsize         int                         800
# printfigs         bool                        False
# pylab             module                      <module 'pylab' from '/Us<...>site-packages/pylab.pyc'>
# r_value           float64                     -0.762864175053
# slope             float64                     -70191.6903083
# sm                module                      <module 'statsmodels.api'<...>ges/statsmodels/api.pyc'>
# sp                module                      <module 'scipy' from '/Us<...>ages/scipy/__init__.pyc'>
# spring            list                        n=3
# springend         int                         30
# springenddate     str                         2012-6-30
# springstartdate   str                         2012-4-01
# stats             module                      <module 'scipy.stats' fro<...>cipy/stats/__init__.pyc'>
# std_err           float64                     26604.8913121
# strt              Timestamp                   2012-04-20 00:00:00
# summer            list                        n=3
# summerend         int                         30
# summerenddate     str                         2012-9-30
# summerstartdate   str                         2012-7-01
# tickfont          int                         28
# titfont           int                         36
# titlefont         int                         40
# ttl               str                         Averge Growing Season NEE vs Ablation Slope
# warm              list                        n=5
# warmend           int                         30
# warmenddate       str                         2012-9-30
# warmstartdate     str                         2012-5-01
# winter            list                        n=3
# winterend         int                         31
# winterenddate     str                         2012-3-31
# winterstartdate   str                         2012-1-01
# wx                DataFrame                               station     v<...>n[4031 rows x 28 columns]
# wyears            Int64Index                  Int64Index([2006, 2007, 2<...>11, 2012], dtype='int64')
# wyrs              str                         12
# x                 Series                      2006    0.1012394\n2007  <...>lationrate, dtype: object
# x2                float64                     0.398560904123
# x3                Series                      2006    0.1012394\n2007  <...>lationrate, dtype: object
# xlab              str                         Ablation Slope [cm/d]
# y                 Series                      2006    1.191419\n2007   <...>titioning, dtype: float64
# y2                float64                     -157446.011043
# y3                Series                      2006   -152805.137143\n20<...>veGrowNEE, dtype: float64
# year              int64                       2012
# ylab              str                         NEE [mm mol C/day]
# yvals             Series                      2006   -148066.2\n2007   <...>lationrate, dtype: object

# %%
pylab.rcParams['figure.figsize'] = (22.0, 11.0)
printfigs = False
wyrs = ['06','07','08','09','10','11','12']
annotatey = [350,345,340,0.51,0.46,0.43,0.4]

ttl = 'Growing Season ET vs Precipitation Magnitude'
x = P.wyP
xlab = 'P [mm]'
y = ET.growET
ylab = 'ET [mm]'
annotatex = .1
out = './figures/agu14_figs/growET_vs_AblationSlp_CRN.pdf'


#######################################
x3 = x
y3 = y

slope, intercept, r_value, p_value, std_err = stats.linregress(x,y)
yvals = linpred(slope, intercept, x)


plt.scatter(x, y, pointsize, c = 'k', edgecolor='none')
ax = plt.gca()


#cb = plt.colorbar()
#cb.set_label('Water Year', fontsize = axfont)

plt.title(ttl, fontsize = titlefont)
plt.ylabel(ylab, fontsize = axfont)
plt.xlabel(xlab, fontsize = axfont)
plt.plot(x, yvals, 'r-', lw = 2)

plt.setp(ax.get_xticklabels(), fontsize=axtickfont)
plt.setp(ax.get_yticklabels(), fontsize=axtickfont)
#cb.ax.tick_params(labelsize=axtickfont) 

#plt.legend(['All data'],'lower left', fontsize = legendfontsize)

EQ = 'y = '+str(round(slope,3))+'x + '+str(round(intercept,3))

#plt.text(annotatex,annotatey[0],'**All Data:**', fontsize = eqtext)
#plt.text(annotatex,annotatey[0],EQ, fontsize = eqtext)
#plt.text(annotatex,annotatey[1],'r$^2$: '+str(round(r_value**2,3)), fontsize = eqtext)
#plt.text(annotatex,annotatey[2],'pValue: ' + str(round(p_value,3)), fontsize = eqtext)

print EQ
print 'r$^2$: '+str(round(r_value**2,3))
print 'pValue: ' + str(round(p_value,3))

for x2, y2, wyrs in zip(x3, y3, wyrs):
    # Annotate the points 5 _points_ above and to the left of the vertex
    ax.annotate('{}'.format(wyrs), xy=(x2,y2), xytext=(-17,17), ha='left',
                textcoords='offset points', fontsize=25)
    

#plt.text(.5,0.83,'A', fontsize = eqtext+30);
    
#plt.text(x,y,wyrs);
#plt.show

if printfigs == True:
    plt.savefig(out,transparent = True, bbox_inches = 'tight')
# Out:
# y = -0.074x + 418.524
# r$^2$: 0.136
# pValue: 0.415

# %% [markdown]
# **Figure 2:** The relationship from Figure 1 holds when only growing season ET (date of peak SWE to September 30th) is considered.

# %%
ttl = 'Growing Season Partitioning vs Peak SWE Fraction'
x = MET.peakSWEFrac
xlab = 'Peak SWE Fraction [1]'
y = MET.growPartitioning
ylab = 'Partitioning [1]'

exclude = [2008]

slope, intercept, r_value, p_value, std_err = stats.linregress(x,y)
yvals = linpred(slope, intercept, x)


plt.scatter(x, y, 100, c = SWE.index)
cb = plt.colorbar()
cb.set_label('Water Year', fontsize = axfont)

plt.title(ttl, fontsize = titlefont)
plt.ylabel(ylab, fontsize = axfont)
plt.xlabel(xlab, fontsize = axfont)
plt.plot(x, yvals, 'r-')


## regression without 2008

x = x[x.index!=exclude]
y = y[y.index!=exclude]

slope2, intercept2, r_value2, p_value2, std_err2 = stats.linregress(x,y)
yvals = linpred(slope2, intercept2, x)

plt.plot(x, yvals, 'b-')
############################################
print '**With 2008:**'               
print 'pValue: ' + str(p_value)
print 'Slope: ' + str(slope)
print 'Intercept: ' + str(intercept)
print
print '**Without 2008:**'
print 'pValue: ' + str(p_value2)
print 'Slope: ' + str(slope2)
print 'Intercept: ' + str(intercept2)
# Out:
# **With 2008:**
# pValue: 0.291128631777
# Slope: -0.681129812317
# Intercept: 0.552486059268
#
# **Without 2008:**
# pValue: 0.336292904164
# Slope: -0.674909567439
# Intercept: 0.55804159531

# %%
ttl = 'Growing Season Partitioning vs Snow Fraction'
x = P.snowFraction
xlab = 'Snow Fraction [1]'
y = MET.growPartitioning
ylab = 'Partitioning [1]'

exclude = [2008]

slope, intercept, r_value, p_value, std_err = stats.linregress(x,y)
yvals = linpred(slope, intercept, x)


plt.scatter(x, y, 100, c = SWE.index)
cb = plt.colorbar()
cb.set_label('Water Year', fontsize = axfont)

plt.title(ttl, fontsize = titlefont)
plt.ylabel(ylab, fontsize = axfont)
plt.xlabel(xlab, fontsize = axfont)
plt.plot(x, yvals, 'r-')

## regression without 2008

x = x[x.index!=exclude]
y = y[y.index!=exclude]

slope2, intercept2, r_value2, p_value2, std_err2 = stats.linregress(x,y)
yvals = linpred(slope2, intercept2, x)

plt.plot(x, yvals, 'b-')
############################################
print '**With 2008:**'               
print 'pValue: ' + str(p_value)
print 'Slope: ' + str(slope)
print 'Intercept: ' + str(intercept)
print
print '**Without 2008:**'
print 'pValue: ' + str(p_value2)
print 'Slope: ' + str(slope2)
print 'Intercept: ' + str(intercept2)
# Out:
# **With 2008:**
# pValue: 0.49223519483
# Slope: -0.308978421175
# Intercept: 0.615336242041
#
# **Without 2008:**
# pValue: 0.586306793667
# Slope: -0.272770504024
# Intercept: 0.601611691214

# %%
printfigs = True
wyrs = ['06','07','08','09','10','11','12']
ttl = 'Growing Season Partitioning vs Water Year P'
x = P.wyP
xlab = 'Precipitation [mm]'
y = MET.growPartitioning
ylab = 'ET/P [1]'
out = './figures/agu14_figs/gsET_vs_Precip_CRN.pdf'
annotatex = 900
annotatey = [0.58,0.56,0.54,0.79,0.76,0.74,0.72,0.70]

#######################################

x3 = x
y3 = y

exclude = [2008]

slope, intercept, r_value, p_value, std_err = stats.linregress(x,y)
yvals = linpred(slope, intercept, x)


plt.scatter(x, y, pointsize, c = 'k', edgecolor='none')
ax = plt.gca()


#cb = plt.colorbar()
#cb.set_label('Water Year', fontsize = axfont)

plt.title(ttl, fontsize = titlefont)
plt.ylabel(ylab, fontsize = axfont)
plt.xlabel(xlab, fontsize = axfont)
plt.plot(x, yvals, 'r-')

plt.setp(ax.get_xticklabels(), fontsize=axtickfont)
plt.setp(ax.get_yticklabels(), fontsize=axtickfont)
#cb.ax.tick_params(labelsize=axtickfont) 

#plt.legend(['All data', 'Without 2008'],'lower left', fontsize = legendfontsize)

EQ = 'y = '+str(round(slope,3))+'x + '+str(round(intercept,3))

#plt.text(annotatex,annotatey[0],'**All Data:**', fontsize = eqtext)
plt.text(annotatex,annotatey[0],EQ, fontsize = eqtext)
plt.text(annotatex,annotatey[1],'r$^2$: '+str(round(r_value**2,3)), fontsize = eqtext)
plt.text(annotatex,annotatey[2],'pValue: ' + str(round(p_value,3)), fontsize = eqtext)

for x2, y2, wyrs in zip(x3, y3, wyrs):
    # Annotate the points 5 _points_ above and to the left of the vertex
    ax.annotate('{}'.format(wyrs), xy=(x2,y2), xytext=(-17,17), ha='left',
                textcoords='offset points', fontsize=25)

#plt.text(x,y,wyrs);
#plt.show

if printfigs == True:
    plt.savefig(out,transparent = True, bbox_inches = 'tight')

# %%
printfigs=True
wyrs = ['06','07','08','09','10','11','12']
ttl = 'Growing Season Partitioning vs Cool Season P'
x = P.coolP
xlab = 'Precipitation [mm]'
y = MET.growPartitioning
ylab = 'ET/P [1]'
out = './figures/agu14_figs/gsET_vs_CoolPrecip_CRN.pdf'
annotatey = [0.58,0.56,0.54,0.79,0.76,0.74,0.72,0.70]
annotatex = 575

#######################################

x3 = x
y3 = y

slope, intercept, r_value, p_value, std_err = stats.linregress(x,y)
yvals = linpred(slope, intercept, x)


plt.scatter(x, y, pointsize, c = 'k', edgecolor='none')
ax = plt.gca()


#cb = plt.colorbar()
#cb.set_label('Water Year', fontsize = axfont)

plt.title(ttl, fontsize = titlefont)
plt.ylabel(ylab, fontsize = axfont)
plt.xlabel(xlab, fontsize = axfont)
plt.plot(x, yvals, 'r-')

plt.setp(ax.get_xticklabels(), fontsize=axtickfont)
plt.setp(ax.get_yticklabels(), fontsize=axtickfont)
#cb.ax.tick_params(labelsize=axtickfont) 

#plt.legend(['All data', 'Without 2008'],'lower left', fontsize = legendfontsize)

EQ = 'y = '+str(round(slope,3))+'x + '+str(round(intercept,3))

#plt.text(annotatex,annotatey[0],'**All Data:**', fontsize = eqtext)
plt.text(annotatex,annotatey[0],EQ, fontsize = eqtext)
plt.text(annotatex,annotatey[1],'r$^2$: '+str(round(r_value**2,3)), fontsize = eqtext)
plt.text(annotatex,annotatey[2],'pValue: ' + str(round(p_value,3)), fontsize = eqtext)

for x2, y2, wyrs in zip(x3, y3, wyrs):
    # Annotate the points 5 _points_ above and to the left of the vertex
    ax.annotate('{}'.format(wyrs), xy=(x2,y2), xytext=(-17,17), ha='left',
                textcoords='offset points', fontsize=25)

#plt.text(x,y,wyrs);
#plt.show

if printfigs == True:
    plt.savefig(out,transparent = True, bbox_inches = 'tight')

# %% [markdown]
# This suggests that cool season P magnitude controls how P is partitioned between ET and R

# %%
printfigs = True

wyrs = ['06','07','08','09','10','11','12']
ttl = 'Growing Season Partitioning vs Warm Season P'
x = P.warmP
xlab = 'Precipitation [mm]'
y = MET.growPartitioning
ylab = 'ET/P [1]'
out = './figures/agu14_figs/gsET_vs_WarmPrecip.pdf'
annotatey = [0.58,0.56,0.54,0.79,0.76,0.74,0.72,0.70]

annotatex = 350

#######################################

x3 = x
y3 = y

slope, intercept, r_value, p_value, std_err = stats.linregress(x,y)
yvals = linpred(slope, intercept, x)


plt.scatter(x, y, pointsize, c = 'k', edgecolor='none')
ax = plt.gca()


#cb = plt.colorbar()
#cb.set_label('Water Year', fontsize = axfont)

plt.title(ttl, fontsize = titlefont)
plt.ylabel(ylab, fontsize = axfont)
plt.xlabel(xlab, fontsize = axfont)
plt.plot(x, yvals, 'r-')

plt.setp(ax.get_xticklabels(), fontsize=axtickfont)
plt.setp(ax.get_yticklabels(), fontsize=axtickfont)
#cb.ax.tick_params(labelsize=axtickfont) 
plt.ylim([0.3,.6])

#plt.legend(['All data', 'Without 2008'],'lower left', fontsize = legendfontsize)

EQ = 'y = '+str(round(slope,3))+'x + '+str(round(intercept,3))

#plt.text(annotatex,annotatey[0],'**All Data:**', fontsize = eqtext)
plt.text(annotatex,annotatey[0],EQ, fontsize = eqtext)
plt.text(annotatex,annotatey[1],'r$^2$: '+str(round(r_value**2,3)), fontsize = eqtext)
plt.text(annotatex,annotatey[2],'pValue: ' + str(round(p_value,3)), fontsize = eqtext)

for x2, y2, wyrs in zip(x3, y3, wyrs):
    # Annotate the points 5 _points_ above and to the left of the vertex
    ax.annotate('{}'.format(wyrs), xy=(x2,y2), xytext=(-17,17), ha='left',
                textcoords='offset points', fontsize=25)

#plt.text(x,y,wyrs);
#plt.show

if printfigs == True:
    plt.savefig(out,transparent = True, bbox_inches = 'tight')

# %% [markdown]
# This suggests that warm season P has little bearing on how growing season ET is paritioned.

# %%
ttl = 'Growing Season Partitioning vs Peak SWE'
x = SWE.peakswe
xlab = 'SWE [mm]'
y = MET.growPartitioning
ylab = 'Partitioning [1]'

exclude = [2008]

slope, intercept, r_value, p_value, std_err = stats.linregress(x,y)
yvals = linpred(slope, intercept, x)


plt.scatter(x, y, 100, c = SWE.index, edgecolor='none')
cb = plt.colorbar()
cb.set_label('Water Year', fontsize = 18)

plt.title(ttl, fontsize = 24)
plt.ylabel(ylab, fontsize = 18)
plt.xlabel(xlab, fontsize = 18)
plt.plot(x, yvals, 'r-')


## regression without 2008

x = x[x.index!=exclude]
y = y[y.index!=exclude]

slope2, intercept2, r_value2, p_value2, std_err2 = stats.linregress(x,y)
yvals = linpred(slope2, intercept2, x)

plt.plot(x, yvals, 'b-')
############################################
print '**With 2008:**'               
print 'pValue: ' + str(p_value)
print 'Slope: ' + str(slope)
print 'Intercept: ' + str(intercept)
print
print '**Without 2008:**'
print 'pValue: ' + str(p_value2)
print 'Slope: ' + str(slope2)
print 'Intercept: ' + str(intercept2)
# Out:
# **With 2008:**
# pValue: 0.0683565218574
# Slope: -0.00110773723085
# Intercept: 0.585824235112
#
# **Without 2008:**
# pValue: 0.0933518548828
# Slope: -0.00109814072755
# Intercept: 0.590872159774

# %% [markdown]
# This is also significant when 2008 is removed. Why is this?

# %%
pylab.rcParams['figure.figsize'] = (22.0, 11.0)

wyrs = ['06','07','08','09','10','11','12']
ttl = 'Growing Season Partitioning vs Warm Season P'
x = SWE.peakswe
xlab = 'Peak SWE [mm]'
y = MET.growPartitioning
ylab = 'ET/P [1]'
out = './figures/gsET_vs_PeakSWE.pdf'
annotatey = [0.89,0.86,0.83,0.80,0.76,0.73,0.70,0.67]

annotatex = 390

#######################################

x3 = x
y3 = y

exclude = [2008]

slope, intercept, r_value, p_value, std_err = stats.linregress(x,y)
yvals = linpred(slope, intercept, x)


plt.scatter(x, y, pointsize, c = 'k', edgecolor='none')
ax = plt.gca()


#cb = plt.colorbar()
#cb.set_label('Water Year', fontsize = axfont)

plt.title(ttl, fontsize = titlefont)
plt.ylabel(ylab, fontsize = axfont)
plt.xlabel(xlab, fontsize = axfont)
plt.plot(x, yvals, 'r-')


## regression without 2008

x = x[x.index!=exclude]
y = y[y.index!=exclude]

slope2, intercept2, r_value2, p_value2, std_err2 = stats.linregress(x,y)
yvals = linpred(slope2, intercept2, x)

plt.plot(x, yvals, 'b-')

plt.setp(ax.get_xticklabels(), fontsize=axtickfont)
plt.setp(ax.get_yticklabels(), fontsize=axtickfont)
#cb.ax.tick_params(labelsize=axtickfont) 
plt.ylim([0.3,1])
plt.legend(['All data', 'Without 2008'],'lower left', fontsize = legendfontsize)

EQ = 'y = '+str(round(slope,3))+'x + '+str(round(intercept,3))

plt.text(annotatex,annotatey[0],'**All Data:**', fontsize = eqtext)
plt.text(annotatex,annotatey[1],EQ, fontsize = eqtext)
plt.text(annotatex,annotatey[2],'r$^2$: '+str(round(r_value**2,3)), fontsize = eqtext)
plt.text(annotatex,annotatey[3],'pValue: ' + str(round(p_value,3)), fontsize = eqtext)

EQ = 'y = '+str(round(slope2,3))+'x + '+str(round(intercept2,3))

plt.text(annotatex,annotatey[4],'**Without 2008:**', fontsize = eqtext)
plt.text(annotatex,annotatey[5],EQ, fontsize = eqtext)
plt.text(annotatex,annotatey[6],'r$^2$: '+str(round(r_value2**2,3)), fontsize = eqtext)
plt.text(annotatex,annotatey[7],'pValue: ' + str(round(p_value2,3)), fontsize = eqtext)

for x2, y2, wyrs in zip(x3, y3, wyrs):
    # Annotate the points 5 _points_ above and to the left of the vertex
    ax.annotate('{}'.format(wyrs), xy=(x2,y2), xytext=(-17,17), ha='left',
                textcoords='offset points', fontsize=25)

#plt.text(x,y,wyrs);
#plt.show

if printfigs == True:
    plt.savefig(out,transparent = True, bbox_inches = 'tight')

# %%
pylab.rcParams['figure.figsize'] = (22.0, 11.0)
printfigs=True

wyrs = ['06','07','08','09','10','11','12']
ttl = 'Como Creek, CO'
x = SWE.peakswe
xlab = 'Peak SWE [cm]'
y = ET.aveGrowET
ylab = 'Average Growing Season ET [mm/day]'
out = './figures/agu14_figs/AveGrowET_vs_PeakSWE_CRN.pdf'
annotatey = [2.8,2.7,2.6]

annotatex = 2

#######################################

x3 = x
y3 = y

exclude = [2008]

slope, intercept, r_value, p_value, std_err = stats.linregress(x,y)
yvals = linpred(slope, intercept, x)


plt.scatter(x, y, pointsize, c = 'k', edgecolor='none')
ax = plt.gca()


#cb = plt.colorbar()
#cb.set_label('Water Year', fontsize = axfont)

plt.title(ttl, fontsize = titlefont)
plt.ylabel(ylab, fontsize = axfont)
plt.xlabel(xlab, fontsize = axfont)
plt.plot(x, yvals, 'r-', lw = 2)

plt.xlim([0,30])
plt.ylim([1.5,3.])

plt.setp(ax.get_xticklabels(), fontsize=axtickfont)
plt.setp(ax.get_yticklabels(), fontsize=axtickfont)
EQ = 'y = '+str(round(slope,3))+'x + '+str(round(intercept,3))

plt.text(annotatex,annotatey[0],EQ, fontsize = eqtext)
plt.text(annotatex,annotatey[1],'r$^2$: '+str(round(r_value**2,3)), fontsize = eqtext)
plt.text(annotatex,annotatey[2],'pValue: ' + str(round(p_value,3)), fontsize = eqtext)

for x2, y2, wyrs in zip(x3, y3, wyrs):
    # Annotate the points 5 _points_ above and to the left of the vertex
    ax.annotate('{}'.format(wyrs), xy=(x2,y2), xytext=(-12,17), ha='left',
                textcoords='offset points', fontsize=25)

#plt.text(x,y,wyrs);
#plt.show

if printfigs == True:
    plt.savefig(out,transparent = True, bbox_inches = 'tight')

# %%
#printfigs = True

pylab.rcParams['figure.figsize'] = (22.0, 11.0)

wyrs = ['04','05','06','07','08','09','10','11','12']
ttl = 'Growing Season Partitioning SWE vs Ablation Rate'
x = SWE.ablationrate
xlab = 'Ablation Rate [mm/Day]'
y = MET.wyGrowPartitioningSWE
ylab = 'ET/PeakSWE [1]'
out = './figures/gsETSWE_vs_PeakSWE_CRN.pdf'
annotatey = [1.72,1.65,1.58,1.51]

annotatex = 1.5

#######################################

x3 = x
y3 = y

exclude = [2008]

slope, intercept, r_value, p_value, std_err = stats.linregress(x,y)
yvals = linpred(slope, intercept, x)


plt.scatter(x, y, pointsize, c = 'k', edgecolor='none')
ax = plt.gca()


#cb = plt.colorbar()
#cb.set_label('Water Year', fontsize = axfont)

plt.title(ttl, fontsize = titlefont)
plt.ylabel(ylab, fontsize = axfont)
plt.xlabel(xlab, fontsize = axfont)
plt.plot(x, yvals, 'r-')


## regression without 2008

#x = x[x.index!=exclude]
#y = y[y.index!=exclude]

#slope2, intercept2, r_value2, p_value2, std_err2 = stats.linregress(x,y)
#yvals = linpred(slope2, intercept2, x)

#plt.plot(x, yvals, 'b-')

plt.setp(ax.get_xticklabels(), fontsize=axtickfont)
plt.setp(ax.get_yticklabels(), fontsize=axtickfont)
#cb.ax.tick_params(labelsize=axtickfont) 
#plt.ylim([0.3,1])
#plt.legend(['All data', 'Without 2008'],'lower left', fontsize = legendfontsize)

EQ = 'y = '+str(round(slope,3))+'x + '+str(round(intercept,3))

plt.text(annotatex,annotatey[0],'**All Data:**', fontsize = eqtext)
plt.text(annotatex,annotatey[1],EQ, fontsize = eqtext)
plt.text(annotatex,annotatey[2],'r$^2$: '+str(round(r_value**2,3)), fontsize = eqtext)
plt.text(annotatex,annotatey[3],'pValue: ' + str(round(p_value,3)), fontsize = eqtext)

#EQ = 'y = '+str(round(slope2,3))+'x + '+str(round(intercept2,3))

#plt.text(annotatex,annotatey[4],'**Without 2008:**', fontsize = eqtext)
#plt.text(annotatex,annotatey[5],EQ, fontsize = eqtext)
#plt.text(annotatex,annotatey[6],'r$^2$: '+str(round(r_value2**2,3)), fontsize = eqtext)
#plt.text(annotatex,annotatey[7],'pValue: ' + str(round(p_value2,3)), fontsize = eqtext)

for x2, y2, wyrs in zip(x3, y3, wyrs):
    # Annotate the points 5 _points_ above and to the left of the vertex
    ax.annotate('{}'.format(wyrs), xy=(x2,y2), xytext=(-17,17), ha='left',
                textcoords='offset points', fontsize=25)

#plt.text(x,y,wyrs);
#plt.show

#if printfigs == True:
#    plt.savefig(out,transparent = True, bbox_inches = 'tight')

# %% [markdown]
# # Generate some method's Figures:

# %%
afx3 = afx.resample('d',how='sum')

# %%
plt.plot(afx3['2005-09-01':'2006-11-01'].index, afx3['2005-09-01':'2006-11-01'].tot_ET, lw = 2, c = 'c')
plt.axhline(0,lw=2,c='k')
plt.axvline('2005-10-01',c='k', lw = 2)
plt.axvline('2006-09-30',c='k', lw = 2)
plt.axvline(SWE.loc[2006].peakswedate, c='r',lw=2)

plt.title('Growing Season ET', fontsize = titlefont)
plt.ylabel('Vapor Flux [mm/day]', fontsize = axfont)

ax = plt.gca()
plt.setp(ax.get_xticklabels(), fontsize=axtickfont)
plt.setp(ax.get_yticklabels(), fontsize=axtickfont);
if printfigs == True:
    plt.savefig('./figures/growing_season_et.pdf',transparent = True, bbox_inches = 'tight')

# %%
plt.plot(niwot['2005-09-01':'2006-11-01'].index, niwot['2005-09-01':'2006-11-01'].swe, lw = 2, c = 'b');
plt.axhline(0,lw=2,c='k');
plt.axvline('2005-10-01',c='k', lw = 2);
plt.axvline('2006-09-30',c='k', lw = 2);
plt.axvline(SWE.loc[2006].peakswedate, c='r',lw=2);
plt.axvline(SWE.loc[2006].snowfreedate, c='r',lw=2);

plt.plot([SWE.loc[2006].peakswedate, SWE.loc[2006].snowfreedate], [SWE.loc[2006].peakswe, 0], 'k--', lw=2);

plt.title('Snowpack Metrics', fontsize = titlefont);
plt.ylabel('SWE [mm]', fontsize = axfont);

ax = plt.gca();
plt.setp(ax.get_xticklabels(), fontsize=axtickfont);
plt.setp(ax.get_yticklabels(), fontsize=axtickfont);

if printfigs == True:
    plt.savefig('./figures/snowpack_metrics.pdf',transparent = True, bbox_inches = 'tight')

# %% [markdown]
# ### Make some general Discussion Plots

# %%
pylab.rcParams['figure.figsize'] = (18.0, 8)

cb = pylab.get_cmap('Set2')
colors = cb(linspace(0.,1.,3))

ind = arange(11)
width = 0.2
plt.bar(ind-width, ET.wyET, width = width, edgecolor='k', facecolor=colors[0])
plt.bar(ind, P.wyP, width = width, edgecolor='k', facecolor=colors[1])
plt.bar(ind+width, SWE.peakswe, edgecolor = 'k', facecolor = colors[2],width=width)

ax = plt.gca()
ax.set_xticks(ind+width)
ax.set_xticklabels(('2002','2003','2004','2005','2006','2007','2008','2009','2010','2011','2012'),
                   fontsize = 24, rotation = -45);
plt.setp(ax.get_yticklabels(), fontsize=24);
plt.legend(['ET','P','Peak SWE'],'upper left', fontsize=20)
plt.ylabel('[mm]', fontsize = 30)
plt.title('ET, P, and SWE Interannual Variability', fontsize = 34)
plt.ylim([0,1000]);

if printfigs == True:
    plt.savefig('./figures/wateryear_bars.pdf',transparent = True, bbox_inches = 'tight')

# %%
pylab.rcParams['figure.figsize'] = (20.0, 5)

plt.plot(niwot['2001-10-01':'2012-09-30'].index, niwot['2001-10-01':'2012-09-30'].swe, lw=2, c='c')
ax = plt.gca()
plt.setp(ax.get_yticklabels(), fontsize=24);
plt.setp(ax.get_xticklabels(), fontsize=24);
plt.title('Niwot SNOTEL', fontsize=34)
plt.ylabel('SWE [mm]',fontsize = 30)

if printfigs == True:
    plt.savefig('./figures/niwot_snotel.pdf',transparent = True, bbox_inches = 'tight')

# %% [markdown]
# ## Calculate Partial R2 for a regression of Growing Season ET and ablation slope and swe magnitude

# %%
import statsmodels.api as sm
from statsmodels.stats.api import anova_lm

# %%
X = SWE[['ablationrate']]
Y = ET['growET']

# %%
X = sm.add_constant(X)
mod = sm.OLS(Y,X)
est = mod.fit()

# %%
est.ssr
# Out:
# 2407.7800920789496

# %%
est.summary2()
# Out:
# <class 'statsmodels.iolib.summary2.Summary'>
# """
#                 Results: Ordinary least squares
# ===============================================================
# Model:                 OLS       AIC:                   79.8440
# Dependent Variable:    growET    BIC:                   80.2385
# No. Observations:      9         Log-Likelihood:        -37.922
# Df Model:              1         F-statistic:           12.18
# Df Residuals:          7         Prob (F-statistic):    0.0101
# R-squared:             0.635     Scale:                 343.97
# Adj. R-squared:        0.583
# ---------------------------------------------------------------
#               Coef.   Std.Err.    t    P>|t|   [0.025   0.975]
# ---------------------------------------------------------------
# const        423.8221  15.2773 27.7419 0.0000 387.6970 459.9473
# ablationrate  -4.7631   1.3650 -3.4896 0.0101  -7.9907  -1.5355
# ---------------------------------------------------------------
# Omnibus:              1.935       Durbin-Watson:          0.754
# Prob(Omnibus):        0.380       Jarque-Bera (JB):       0.928
# Skew:                 0.763       Prob(JB):               0.629
# Kurtosis:             2.615       Condition No.:          28
# ===============================================================
#
# """

# %%
SWE.columns
# Out:
# Index([u'peakswe', u'peakswedate', u'snowfreedate', u'ablationrate', u'ablationseason', u'growseasonlength'], dtype='object')

# %%
ET.columns
# Out:
# Index([u'wyET', u'growET', u'aveGrowET'], dtype='object')

# %%
anova_lm(mod)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-150-7ad215b23b58> in <module>()
# ----> 1 anova_lm(mod)
#
# /Users/barnhatb/anaconda/lib/python2.7/site-packages/statsmodels/stats/anova.pyc in anova_lm(*args, **kwargs)
#     323     if len(args) == 1:
#     324         model = args[0]
# --> 325         return anova_single(model, **kwargs)
#     326
#     327     try:
#
# /Users/barnhatb/anaconda/lib/python2.7/site-packages/statsmodels/stats/anova.pyc in anova_single(model, **kwargs)
#      55         robust = robust.lower()
#      56
# ---> 57     endog = model.model.endog
#      58     exog = model.model.exog
#      59     nobs = exog.shape[0]
#
# AttributeError: 'OLS' object has no attribute 'model'

# %%
labfont = 30
titfont = 36
tickfont = 28
lw = 4
legfont = 30

plt.figure(figsize=[22,11]);
ax = plt.gca();
ax2 = ax.twinx();

lns1 = ax.plot(ET.index, ET.aveGrowET,'c-',lw=lw, label = 'Average ET');
ax.set_ylabel('Average Growing Season ET [mm/day]', fontsize = labfont);

lns2 = ax2.plot(SWE.index, SWE.peakswe,'b-',lw=lw,label = 'Peak SWE');
ax2.set_ylabel('SWE [cm]', fontsize = labfont);

lns = lns1+lns2
labs = [l.get_label() for l in lns];
ax.legend(lns, labs, loc='upper left', fontsize=legfont);
plt.xlim([2005,2013]);
ax.set_ylim([1.5,3])
ax2.set_ylim([0,25])

plt.title('Como Creek, CO', fontsize=titfont);
ax.set_xticklabels(['2005','2006','2007','2008','2009','2010','2011','2012','2013'], fontsize=tickfont);
plt.setp(ax.get_yticklabels(), fontsize=tickfont);
plt.setp(ax2.get_yticklabels(), fontsize=tickfont);

plt.savefig('./figures/agu14_figs/Como_gsETvsPeakSWE_TS.pdf',transparent = True, bbox_inches='tight')
