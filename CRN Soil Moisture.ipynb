# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import pylab
import matplotlib.pyplot as plt
import scipy as sp
import glob
import calendar

pylab.rcParams['figure.figsize'] = (22.0, 11.0)

# %%
dat = pd.read_pickle('./data/boulder_co.pcl')

# %%
dat.describe()
# Out:
#        station           vn  long      lat         Tmax         Tmin  \
# count     4031  4031.000000     0  4031.00  4002.000000  4003.000000
# mean     94075     1.880335   NaN    40.04     7.383783    -3.871421
# std          0     0.556089   NaN     0.00     9.567738     7.662364
# min      94075     1.201000   NaN    40.04   -23.800000   -38.500000
# 25%      94075     1.301000   NaN    40.04    -0.100000    -9.100000
# 50%      94075     2.302000   NaN    40.04     7.100000    -2.800000
# 75%      94075     2.404000   NaN    40.04    16.000000     1.900000
# max      94075     2.423000   NaN    40.04    26.500000    13.600000
#
#          Tave_hist     Tave_mod            P           SW     ...       \
# count  4002.000000  4001.000000  3978.000000  4003.000000     ...
# mean      1.776262     1.963709     2.340447    15.485808     ...
# std       8.401602     8.340160     5.303869     7.958884     ...
# min     -30.800000   -30.000000     0.000000     0.000000     ...
# ...

# %%
sm = dat.filter(regex='sm')

# %%
plt.plot(sm['2011-10-01':'2014-09-30'].index,sm['2011-10-01':'2014-09-30'])
plt.legend(['5 cm','10 cm'],loc='upper left', fontsize=16)
