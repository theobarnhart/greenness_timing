# %% [markdown]
# # Investigation of snowmelt partitioning Como Creek, CO
#
# This notebook looks at how snowmelt is partitioned in Como Creek using the Niwot snotel, AFX ET, and runoff from the como creek gauge.

# %%
# %pylab inline
import numpy as np
import pandas as pd
import pylab
import matplotlib.pyplot as plt
import scipy as sp
import glob
from mpl_toolkits.mplot3d import Axes3D
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ## load the discharge data

# %%
obs = pd.read_pickle('/RHESSys/Comocreek/barnhatb/obs/como_specific_discharge_daily.pcl')
obs2 = obs.resample('%W',how='sum')

# %% [markdown]
# ## Load the ET data
#
# ### Header info
# - YEAR : year
# - GAP : unknown, maybe if a gap was present
# - DTIME : day of year (DOY) and decimal time
# - DOY : day of year
# - HRMIN
# - UST  [m/s]
# - TA [deg C] : air temperature
# - WD [deg] : wind direction
# - NEE [umol/m2/s] : Net Ecosystem Exchange
# - FC [umol/m2/s] : Carbon Flux
# - SFC [umol/m2/s]
# - H [W/m2]
# - SH [W/m2]
# - LE [W/m2]
# - SLE [W/m2]
# - FG [W/m2]
# - TS1 [deg C] : Soil temp 1
# - TSdepth1 [cm] : Depth of 1st soil temp.
# - TS2 [deg C] : Soil temp 2
# - TSdepth2 [cm] : Depth of 2nd soil temp.
# - PREC [mm] : precipitation
# - RH [%] : relative humidity
# - PRESS [kPa] : air pressure
# - VPD [umol/mol] : vapor pressure deficit
# - CO2 [kPa] : partial pressure of CO2
# - SWC1 [%] : soil moisture 1
# - SWC2 [%] : soil moisture 2
# - PAR [W/m2] : photosynthetically active radiation
# - Rn [umol/m2/s]  : net radiation
# - Rg [W/m2]
# - Rgdif [W/m2]
# - PARout [umol/m2/s]
# - RgOut [W/m2]
# - Rgl [W/m2]
# - RglOut [W/m2]
# - H2O [mmol/mol]
# - RE [umol/m2/s]
# - GPP [umol/m2/s]
# - CO2top [umol/mol]
# - CO2height [m]
# - APAR [umol/m2/s]
# - PARdif [umol/m2/s]
# - APARpct [%]
# - ZL [unitless]

# %%
afx = pd.read_pickle('./ameriflux/niwot/AFX_niwot.pcl')
afx2 = pd.read_pickle('./ameriflux/niwot/AFX_niwot_yearly.pcl')

# %% [markdown]
# ## Load snotel data

# %%
files = glob.glob('/Users/theodorebarnhart/Dropbox/CUB/ET magnitude and snowmelt/data/snotel/niwot_663/daily/*.csv')
n = len(files)

# %%
files
# Out:
# ['/Users/theodorebarnhart/Dropbox/CUB/ET magnitude and snowmelt/data/snotel/niwot_663/daily/663_STAND_YEAR=2001.csv',
#  '/Users/theodorebarnhart/Dropbox/CUB/ET magnitude and snowmelt/data/snotel/niwot_663/daily/663_STAND_YEAR=2002.csv',
#  '/Users/theodorebarnhart/Dropbox/CUB/ET magnitude and snowmelt/data/snotel/niwot_663/daily/663_STAND_YEAR=2003.csv',
#  '/Users/theodorebarnhart/Dropbox/CUB/ET magnitude and snowmelt/data/snotel/niwot_663/daily/663_STAND_YEAR=2004.csv',
#  '/Users/theodorebarnhart/Dropbox/CUB/ET magnitude and snowmelt/data/snotel/niwot_663/daily/663_STAND_YEAR=2005.csv',
#  '/Users/theodorebarnhart/Dropbox/CUB/ET magnitude and snowmelt/data/snotel/niwot_663/daily/663_STAND_YEAR=2006.csv',
#  '/Users/theodorebarnhart/Dropbox/CUB/ET magnitude and snowmelt/data/snotel/niwot_663/daily/663_STAND_YEAR=2007.csv',
#  '/Users/theodorebarnhart/Dropbox/CUB/ET magnitude and snowmelt/data/snotel/niwot_663/daily/663_STAND_YEAR=2008.csv',
#  '/Users/theodorebarnhart/Dropbox/CUB/ET magnitude and snowmelt/data/snotel/niwot_663/daily/663_STAND_YEAR=2009.csv',
#  '/Users/theodorebarnhart/Dropbox/CUB/ET magnitude and snowmelt/data/snotel/niwot_663/daily/663_STAND_YEAR=2010.csv',
#  '/Users/theodorebarnhart/Dropbox/CUB/ET magnitude and snowmelt/data/snotel/niwot_663/daily/663_STAND_YEAR=2011.csv',
#  '/Users/theodorebarnhart/Dropbox/CUB/ET magnitude and snowmelt/data/snotel/niwot_663/daily/663_STAND_YEAR=2012.csv']

# %%
fl = files[0]

# %%
niwot = pd.read_csv(fl, skiprows=1, header=True, parse_dates=True, index_col='Date')
#year = int(fl.split('_')[-1].split('=')[-1].split('.')[0])
#niwot.index = niwot.Date

# %%
for i in xrange(1,n):
    fl = files[i]
    data = pd.read_csv(fl, skiprows=1, header=True, parse_dates=True, index_col='Date')
    niwot = pd.concat([niwot,data])
    
niwot = niwot.sort_index()

# %%
niwot.head()
# Out:
#             Site Id Time  WTEQ.I-1 (in)   PREC.I-1 (in)   TOBS.I-1 (degC)   \
# Date
# 2001-01-01      663  NaN             4.1             4.5              -7.8
# 2001-01-02      663  NaN             4.1             4.5             -12.7
# 2001-01-03      663  NaN             4.1             4.6              -3.1
# 2001-01-04      663  NaN             4.1             4.6              -1.1
# 2001-01-05      663  NaN             4.1             4.6              -1.5
#
#             TMAX.D-1 (degC)   TMIN.D-1 (degC)   TAVG.D-1 (degC)
# Date
# 2001-01-01              -4.0             -10.2              -7.7
# 2001-01-02              -2.2             -14.1              -7.5
# 2001-01-03               0.9             -18.5              -8.0
# 2001-01-04               5.2              -3.2              -0.3
# 2001-01-05               5.6              -1.9               1.1
#
# [5 rows x 8 columns]

# %%
niwot.tail()
# Out:
#             Site Id Time  WTEQ.I-1 (in)   PREC.I-1 (in)   TOBS.I-1 (degC)   \
# Date
# 2012-12-27      663  NaN             3.8             4.9              -9.3
# 2012-12-28      663  NaN             3.8             5.0             -13.7
# 2012-12-29      663  NaN             3.9             5.0              -9.9
# 2012-12-30      663  NaN             3.9             5.0              -2.9
# 2012-12-31      663  NaN             3.9             5.0             -10.7
#
#             TMAX.D-1 (degC)   TMIN.D-1 (degC)   TAVG.D-1 (degC)
# Date
# 2012-12-27               0.0             -12.7              -6.7
# 2012-12-28              -8.3             -15.5             -10.9
# 2012-12-29              -8.1             -14.9             -12.9
# 2012-12-30               1.8             -12.4              -4.7
# 2012-12-31               0.7             -11.3              -6.1
#
# [5 rows x 8 columns]

# %%
cols = ['siteid','time','swe','precip','t','tmax','tmin','tave']

niwot.columns = cols

niwot.swe[niwot.swe < 0] = 0

niwot.swe = (niwot.swe*2.54)*10 # convert in to mm

niwot.precip = (niwot.precip*2.54)*10 # convert in to mm

# %%
niwot.describe()
# Out:
#        siteid          swe       precip            t         tmax  \
# count    4395  4395.000000  4395.000000  4395.000000  4395.000000
# mean      663    99.038039   362.329989    -0.935995     7.794334
# std         0   117.621736   242.438796    10.069446    18.963625
# min       663     0.000000     0.000000   -99.900000   -99.900000
# 25%       663     0.000000   144.780000    -5.250000     1.800000
# 50%       663    43.180000   340.360000     0.100000     9.600000
# 75%       663   180.340000   585.470000     4.900000    18.100000
# max       663   454.660000   894.080000    17.400000    46.700000
#
#               tmin         tave
# count  4395.000000  4395.000000
# mean     -4.334130     1.940842
# std      10.816309    10.723929
# min     -99.900000   -99.900000
# 25%      -8.800000    -3.600000
# 50%      -2.600000     2.500000
# 75%       1.600000     9.100000
# max      13.700000    19.700000
#
# [8 rows x 7 columns]

# %% [markdown]
# ## Precipitation

# %%
wx = pd.read_pickle('/RHESSys/Comocreek/barnhatb/clim/niwot_snotel.pcl')
wx.precip = wx.precip*(100*10)

# %%
wx.describe()
# Out:
#                 swe  precip_accum        ATmax        ATmin        ATave  \
# count  12321.000000  12321.000000  9034.000000  9034.000000  9034.000000
# mean       4.278865     15.432278     9.502558    -4.235635     1.834243
# std        5.060075     10.555857     9.993307     7.470492     7.996622
# min        0.000000      0.000000   -22.777778   -47.777778   -25.000000
# 25%        0.000000      6.000000     1.666667    -9.444444    -3.888889
# 50%        1.900000     14.500000     9.444444    -3.333333     1.666667
# 75%        7.800000     24.500000    17.777778     1.111111     8.333333
# max       21.100000     41.700000    46.666667    13.888889    19.444444
#
#              precip
# count  12321.000000
# mean       2.223763
# std        4.892268
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        2.540000
# max       76.200000
#
# [8 rows x 6 columns]

# %% [markdown]
# ## Plot all the data
#
# ### Discharge

# %%
pylab.rcParams['figure.figsize'] = (22.0, 11.0)

# %%
plt.plot(obs.index, obs.discharge, 'b-')
plt.title('Como Creek Discharge', fontsize = 22)
plt.xlabel('Time', fontsize = 16)
plt.ylabel('Discharge [mm]', fontsize = 16);

# %% [markdown]
# ### ET

# %%
plt.plot(afx.index, afx.tot_ET, 'b-')
plt.title('AFX ET', fontsize = 22)
plt.xlabel('Time', fontsize = 16)
plt.ylabel('ET [mm]', fontsize = 16)
plt.axhline(0, c='w');

# %% [markdown]
# ### SWE

# %%
plt.plot(niwot.index, niwot.swe, 'b-', lw =2)
plt.title('Niwot SnoTel Snowpack', fontsize = 28)
plt.xlabel('Time', fontsize = 18)
plt.ylabel('SWE [mm]', fontsize = 18);
#plt.axis('tight');
plt.savefig('./Niwot_Snopack.png');

# %% [markdown]
# It looks like low swe years are: 2002, 2004, 2010, 2012
#
# High swe years are: 2003, 2007, 2009, 2011
#
# normal swe years: 2005, 2006, 2008

# %% [markdown]
# ## Plot only one year of snowpack

# %%
plt.plot(niwot["2006-10-01":"2007-09-30"].index, niwot["2006-10-01":"2007-09-30"].swe, 'b-', lw = 2);
plt.title("Niwot SnoTel: WY 2007", fontsize=28)
plt.ylabel("SWE [mm]", fontsize=18);
plt.axis('tight')
plt.savefig("./Niwot_Snopack_WY2007.png")

# %%
plt.plot(wx.index, wx.precip, 'b-')
plt.title('Niwot SnoTel Precipitation', fontsize = 22)
plt.xlabel('Time', fontsize = 16)
plt.ylabel('Precipitation [mm]', fontsize = 16)

# %% [markdown]
# ## Calculate Snowpack Metrics
#
# - peak : peakswe [mm]
# - date of peak swe : peakswedate
# - date of zero snow : snowfree date
# - ablation rate : ablrate [mm/day]

# %%
years = range(2005,2013) # generate water years
n = len(years)

SWE = pd.DataFrame(np.zeros([n,6]), columns=['peakswe','peakswedate','snowfreedate','ablrate','P','ablseas'], index=years) # preallocate

# %%
for year in years:
    SWE.loc[year,'peakswe'] = niwot.loc[str(year-1)+'-10-01':str(year)+'-09-30'].swe.max() # extract the peak swe for the water year selected
    SWE.loc[year,'peakswedate'] = niwot.loc[str(year-1)+'-10-01':str(year)+'-09-30'].swe.argmax() # extract the date of peak swe
    SWE.loc[year,'snowfreedate'] = niwot.loc[str(year)+'-01-01':str(year)+'-09-30'].swe.argmin() # extract the first snow free date
    SWE.loc[year, 'P'] = np.sum(wx.loc[str(year-1)+'-10-30':str(year)+'-09-30'].precip)
    
    ## calculate meltout time delta
    timedelta = SWE.loc[year,'snowfreedate'] - SWE.loc[year,'peakswedate']

    SWE.loc[year,'ablrate'] = SWE.loc[year,'peakswe']/timedelta.days # [mm/day]
    SWE.loc[year, 'ablseas'] = int(timedelta.days)

# %% [markdown]
# ## Calculate Total ET and Runoff for water years

# %%
SWE['ET'] = np.zeros([n,1]) # preallocate
SWE['Q'] = np.zeros([n,1])
SWE['wy_et'] = np.zeros([n,1])
SWE['wy_q'] = np.zeros([n,1])

# %%
for year in years:

    # calculate growing season ET from the date of peak swe to the end of the water year.

    strt = SWE.ix[year].peakswedate

    SWE.loc[year,'ET'] = np.sum(afx.loc[str(strt.year)+'-'+str(strt.month)+'-'+str(strt.day):str(year)+'-09-30'].tot_ET)
    SWE.loc[year,'wy_et'] = np.sum(afx.loc[str(year-1)+'-10-01':str(year)+'-09-30'].tot_ET) # compute water year ET
    
    # calculate the discharge from the date of peak swe to the end of the water year. 

    SWE.loc[year,'Q'] = np.sum(obs.loc[str(strt.year)+'-'+str(strt.month)+'-'+str(strt.day):str(year)+'-09-30'].discharge)
    SWE.loc[year,'wy_q'] = np.sum(obs.loc[str(year-1)+'-10-01':str(year)+'-09-30'].discharge) # compute water year discharge

# %% [markdown]
# ## Calculate traditional snow fraction

# %%
n = len(wx)
wx['snow'] = np.zeros([n,1]) # preallocate

for i in xrange(0,n):
    tmpdate = wx.index[i] # get the date of the record for indexing
    if wx.loc[tmpdate,'ATmax'] <= 2:
        wx.loc[tmpdate,'snow'] = wx.loc[tmpdate,'precip']

# %%
wx.tail(50)
# Out:
#                   date   swe  precip_accum      ATmax      ATmin      ATave  \
# 2014-05-07  2014-05-07  12.7          19.2   7.777778  -1.666667   2.222222
# 2014-05-08  2014-05-08  12.9          19.4   4.444444  -2.777778   0.000000
# 2014-05-09  2014-05-09  12.9          19.6   6.111111  -1.111111   1.111111
# 2014-05-10  2014-05-10  13.1          19.9  10.555556  -0.555556   2.777778
# 2014-05-11  2014-05-11  13.3          20.2   1.111111  -6.111111  -2.777778
# 2014-05-12  2014-05-12  14.6          21.4  -2.777778  -7.777778  -6.111111
# 2014-05-13  2014-05-13  15.0          22.3   1.666667 -10.555556  -5.000000
# 2014-05-14  2014-05-14  15.0          22.3   4.444444  -6.666667  -0.555556
# 2014-05-15  2014-05-15  15.0          22.3   7.777778  -1.666667   3.333333
# 2014-05-16  2014-05-16  15.0          22.3  12.222222   1.111111   4.444444
# 2014-05-17  2014-05-17  15.0          22.7  13.333333   0.555556   5.555556
# 2014-05-18  2014-05-18  14.6          22.7  17.777778   0.000000   9.444444
# 2014-05-19  2014-05-19  13.8          22.7  16.666667   1.666667   9.444444
# 2014-05-20  2014-05-20  12.9          22.7  10.555556   0.555556   6.111111
# 2014-05-21  2014-05-21  12.5          22.7  11.666667   0.555556   5.000000
# 2014-05-22  2014-05-22  12.2          23.1  13.333333   0.555556   5.555556
# 2014-05-23  2014-05-23  11.6          23.3  11.666667   0.555556   5.555556
# 2014-05-24  2014-05-24  11.2          23.5   9.444444   1.666667   5.000000
# 2014-05-25  2014-05-25  10.5          24.1   7.222222   0.555556   3.333333
# 2014-05-26  2014-05-26   8.5          24.2  12.777778   1.111111   5.555556
# 2014-05-27  2014-05-27   8.4          24.2  17.222222   2.222222  10.000000
# 2014-05-28  2014-05-28   7.6          24.2  18.888889   1.666667  10.000000
# 2014-05-29  2014-05-29   6.5          24.2  19.444444   2.222222  10.000000
# 2014-05-30  2014-05-30   5.2          24.2  12.222222   1.111111   6.666667
# 2014-05-31  2014-05-31   4.5          24.2  17.222222   1.666667   8.888889
# 2014-06-01  2014-06-01   3.0          24.2  16.666667   2.222222   9.444444
# 2014-06-02  2014-06-02   2.0          24.2  17.222222   0.555556   9.444444
# 2014-06-03  2014-06-03   1.2          24.2  18.888889   2.777778  11.111111
# 2014-06-04  2014-06-04   0.7          24.2  17.222222   1.111111   8.888889
# 2014-06-05  2014-06-05   0.8          23.4  16.111111   0.000000   7.777778
# 2014-06-06  2014-06-06   0.8          23.3  16.666667   0.555556   8.333333
# 2014-06-07  2014-06-07   0.6          23.2  13.888889   1.111111   7.222222
# 2014-06-08  2014-06-08   0.5          23.0  14.444444   0.555556   4.444444
# 2014-06-09  2014-06-09   0.3          22.9  12.222222   0.000000   6.666667
# 2014-06-10  2014-06-10   0.2          22.7  17.777778   5.000000  11.666667
# 2014-06-11  2014-06-11   0.1          22.5  16.666667   3.333333  10.000000
# 2014-06-12  2014-06-12   0.1          22.3  16.666667   2.222222   8.333333
# 2014-06-13  2014-06-13   0.0          22.0  20.555556   2.222222  11.666667
# 2014-06-14  2014-06-14   0.0          21.7  16.111111   3.333333   8.888889
# 2014-06-15  2014-06-15   0.0          21.4  13.888889   0.555556   7.222222
# 2014-06-16  2014-06-16   0.0          21.1  18.888889   2.222222  11.666667
# 2014-06-17  2014-06-17   0.0          20.7  18.333333   3.333333  11.666667
# 2014-06-18  2014-06-18   0.0          20.3  16.111111   2.222222   8.333333
# 2014-06-19  2014-06-19   0.1          20.1  15.555556   1.666667   8.888889
# 2014-06-20  2014-06-20   0.0          19.8  20.000000   1.111111  11.111111
# 2014-06-21  2014-06-21   0.0          19.3  18.333333   2.222222  11.111111
# 2014-06-22  2014-06-22   0.0          19.0  17.222222   4.444444   9.444444
# 2014-06-23  2014-06-23   0.0          18.6  18.333333   2.222222   9.444444
# 2014-06-24  2014-06-24   0.0          18.3  19.444444   2.222222  10.000000
# 2014-06-25  2014-06-25   0.0          17.9  22.222222   4.444444  12.222222
#
#             precip   snow
# 2014-05-07    5.08   0.00
# 2014-05-08    5.08   0.00
# 2014-05-09    7.62   0.00
# 2014-05-10    7.62   0.00
# 2014-05-11   30.48  30.48
# 2014-05-12   22.86  22.86
# 2014-05-13    0.00   0.00
# 2014-05-14    0.00   0.00
# 2014-05-15    0.00   0.00
# 2014-05-16   10.16   0.00
# 2014-05-17    0.00   0.00
# 2014-05-18    0.00   0.00
# 2014-05-19    0.00   0.00
# 2014-05-20    0.00   0.00
# 2014-05-21   10.16   0.00
# 2014-05-22    5.08   0.00
# 2014-05-23    5.08   0.00
# 2014-05-24   15.24   0.00
# 2014-05-25    2.54   0.00
# 2014-05-26    0.00   0.00
# 2014-05-27    0.00   0.00
# 2014-05-28    0.00   0.00
# 2014-05-29    0.00   0.00
# 2014-05-30    0.00   0.00
# 2014-05-31    0.00   0.00
# 2014-06-01    0.00   0.00
# 2014-06-02    0.00   0.00
# 2014-06-03    0.00   0.00
# 2014-06-04    0.00   0.00
# 2014-06-05    0.00   0.00
# 2014-06-06    0.00   0.00
# 2014-06-07    0.00   0.00
# 2014-06-08    0.00   0.00
# 2014-06-09    0.00   0.00
# 2014-06-10    0.00   0.00
# 2014-06-11    0.00   0.00
# 2014-06-12    0.00   0.00
# 2014-06-13    0.00   0.00
# 2014-06-14    0.00   0.00
# 2014-06-15    0.00   0.00
# 2014-06-16    0.00   0.00
# 2014-06-17    0.00   0.00
# 2014-06-18    0.00   0.00
# 2014-06-19    0.00   0.00
# 2014-06-20    0.00   0.00
# 2014-06-21    0.00   0.00
# 2014-06-22    0.00   0.00
# 2014-06-23    0.00   0.00
# 2014-06-24    0.00   0.00
# 2014-06-25    0.00   0.00
#
# [50 rows x 8 columns]

# %%
for year in years:
    SWE.loc[year,'snow'] = np.sum(wx.loc[str(year-1)+'-10-30':str(year)+'-09-30'].snow)

# %%
SWE
# Out:
#      peakswe peakswedate snowfreedate   ablrate       P ablseas          ET  \
# 2005  340.36  2005-05-03   2005-05-28   13.6144  693.42      25  336.624637
# 2006  325.12  2006-03-27   2006-05-17  6.374902  670.56      51  380.840216
# 2007  454.66  2007-04-27   2007-06-03  12.28811   647.7      37  367.622453
# 2008  378.46  2008-04-18   2008-06-02  8.410222  454.66      45  377.225606
# 2009   406.4  2009-04-19   2009-05-25  11.28889  708.66      36  374.337247
# 2010   317.5  2010-04-08   2010-06-02  5.772727   622.3      55  387.884327
# 2011   431.8  2011-05-22   2011-06-13  19.62727  815.34      22  350.368581
# 2012   279.4  2012-03-04   2012-05-16  3.827397  665.48      73  438.903213
#
#                Q       wy_et        wy_q    snow
# 2005  194.473687  544.449574  203.455735  304.80
# 2006  153.831705  618.061701  162.206223  162.56
# 2007  193.602895  630.939326  204.428112  157.48
# 2008  133.787896  641.237630  143.944948  246.38
# 2009  183.481086  609.334106  191.483572  337.82
# 2010  214.310640  592.750001  228.596024  335.28
# 2011  321.991496  648.274141  349.025160  375.92
# 2012   88.558259  640.542938  110.204871  231.14
#
# [8 rows x 11 columns]

# %% [markdown]
# ### normalize ET, Q, ans SWE as a fraction of P

# %%
SWE['RR'] = SWE.Q/SWE.P #[mm/mm]
SWE['ER'] = SWE.ET/SWE.P #[mm/mm]
SWE['SF'] = SWE.peakswe/SWE.P #[mm/mm]
SWE['TSF'] = SWE.snow/SWE.P #[mm/mm]

# %%
SWE
# Out:
#      peakswe peakswedate snowfreedate   ablrate       P ablseas          ET  \
# 2005  340.36  2005-05-03   2005-05-28   13.6144  693.42      25  336.624637
# 2006  325.12  2006-03-27   2006-05-17  6.374902  670.56      51  380.840216
# 2007  454.66  2007-04-27   2007-06-03  12.28811   647.7      37  367.622453
# 2008  378.46  2008-04-18   2008-06-02  8.410222  454.66      45  377.225606
# 2009   406.4  2009-04-19   2009-05-25  11.28889  708.66      36  374.337247
# 2010   317.5  2010-04-08   2010-06-02  5.772727   622.3      55  387.884327
# 2011   431.8  2011-05-22   2011-06-13  19.62727  815.34      22  350.368581
# 2012   279.4  2012-03-04   2012-05-16  3.827397  665.48      73  438.903213
#
#                Q       wy_et        wy_q    snow         RR         ER  \
# 2005  194.473687  544.449574  203.455735  304.80  0.2804558  0.4854556
# 2006  153.831705  618.061701  162.206223  162.56  0.2294078  0.5679435
# 2007  193.602895  630.939326  204.428112  157.48  0.2989083  0.5675814
# 2008  133.787896  641.237630  143.944948  246.38  0.2942592  0.8296873
# 2009  183.481086  609.334106  191.483572  337.82  0.2589127  0.5282325
# 2010  214.310640  592.750001  228.596024  335.28  0.3443848  0.6233076
# 2011  321.991496  648.274141  349.025160  375.92  0.3949168  0.4297208
# 2012   88.558259  640.542938  110.204871  231.14  0.1330743  0.6595288
#
#              SF        TSF
# 2005  0.4908425  0.4395604
# 2006  0.4848485  0.2424242
# 2007  0.7019608  0.2431373
# 2008  0.8324022  0.5418994
# 2009  0.5734767  0.4767025
# 2010  0.5102041  0.5387755
# 2011   0.529595  0.4610592
# 2012  0.4198473  0.3473282
#
# [8 rows x 15 columns]

# %% [markdown]
# # Plots and Regression!

# %%
from scipy import stats

def linpred(slope,intercept,xvals):
    yvals = (xvals*slope)+intercept
    return yvals

# %% [markdown]
# ## Plot ET vs Peak SWE

# %%
plt.plot(SWE.peakswe, SWE.ET, 'ok', markersize = 15)
plt.title('SWE vs total ET', fontsize = 22)
plt.xlabel('Peak SWE [mm]', fontsize = 16)
plt.ylabel('Growing Season ET [mm]', fontsize = 16)

# %% [markdown]
# Not much of a relationship here

# %% [markdown]
# ### Plot Q vs peak SWE

# %%
slope, intercept, r_value, p_value, std_err = stats.linregress(SWE.peakswe,SWE.Q)

plt.plot(SWE.peakswe, SWE.Q, 'ok', markersize = 15)
plt.title('SWE vs total Q', fontsize = 22)
plt.xlabel('Peak SWE [mm]', fontsize = 16)
plt.ylabel('Growing Season Q [mm]', fontsize = 16)

yvals = linpred(slope, intercept, SWE.peakswe)

plt.plot(SWE.peakswe, yvals, 'r-')

# %% [markdown]
# Not much of a relationship here.

# %%
print p_value
# Out:
# 0.12958082801

# %% [markdown]
# ### Plot SF vs ER

# %%
slope, intercept, r_value, p_value, std_err = stats.linregress(SWE.SF,SWE.ER)

plt.plot(SWE.SF, SWE.ER, 'ok', markersize = 15)
plt.title('Peak SWE/P vs total ET', fontsize = 22)
plt.xlabel('Snow Fraction [1]', fontsize = 16)
plt.ylabel('Growing Season Evaporative Fraction [1]', fontsize = 16)

yvals = linpred(slope, intercept, SWE.SF)

plt.plot(SWE.SF, yvals, 'r-')

# %% [markdown]
# So years with greater snow fractions partition proportionally more water to ET than years with lower snow fractions. This looks like the only relationship from this data set with a statisticaly significant relationship at the 0.05 level.
#
#
# - deconvolve this b/c it doesnt fit with the Nature climate change paper.
# - relative snow vs rain.

# %%
print p_value
# Out:
# 0.155452091894

# %%
slope, intercept, r_value, p_value, std_err = stats.linregress(SWE.TSF,SWE.ER)

plt.plot(SWE.TSF, SWE.ER, 'ok', markersize = 15)
plt.title('Traditional snow fraction vs total ET', fontsize = 22)
plt.xlabel('Snow Fraction [1]', fontsize = 16)
plt.ylabel('Growing Season Evaporative Fraction [1]', fontsize = 16)

yvals = linpred(slope, intercept, SWE.TSF)

plt.plot(SWE.TSF, yvals, 'r-')

# %% [markdown]
# The relationship using the traditional snow fraction is not significant...

# %%
print p_value
# Out:
# 0.585557325749

# %% [markdown]
# ### Plot of time of peak vs ER

# %%
SWE['DOM'] = np.zeros([len(SWE),1]) # preallocate
SWE['SFD'] = np.zeros([len(SWE),1])

# %%
# Calculate the day of year of peak SWE and the DOY that the site goes snow free. 
for year in years:
    date = SWE.loc[year,'peakswedate']
    SWE.loc[year,'DOM'] = int(date.strftime('%j'))
    date = SWE.loc[year,'snowfreedate']
    SWE.loc[year,'SFD'] = int(date.strftime('%j'))

# %%
SWE
# Out:
#      peakswe peakswedate snowfreedate   ablrate       P ablseas          ET  \
# 2005  340.36  2005-05-03   2005-05-28   13.6144  693.42      25  336.624637
# 2006  325.12  2006-03-27   2006-05-17  6.374902  670.56      51  380.840216
# 2007  454.66  2007-04-27   2007-06-03  12.28811   647.7      37  367.622453
# 2008  378.46  2008-04-18   2008-06-02  8.410222  454.66      45  377.225606
# 2009   406.4  2009-04-19   2009-05-25  11.28889  708.66      36  374.337247
# 2010   317.5  2010-04-08   2010-06-02  5.772727   622.3      55  387.884327
# 2011   431.8  2011-05-22   2011-06-13  19.62727  815.34      22  350.368581
# 2012   279.4  2012-03-04   2012-05-16  3.827397  665.48      73  438.903213
#
#                Q       wy_et        wy_q    snow         RR         ER  \
# 2005  194.473687  544.449574  203.455735  304.80  0.2804558  0.4854556
# 2006  153.831705  618.061701  162.206223  162.56  0.2294078  0.5679435
# 2007  193.602895  630.939326  204.428112  157.48  0.2989083  0.5675814
# 2008  133.787896  641.237630  143.944948  246.38  0.2942592  0.8296873
# 2009  183.481086  609.334106  191.483572  337.82  0.2589127  0.5282325
# 2010  214.310640  592.750001  228.596024  335.28  0.3443848  0.6233076
# 2011  321.991496  648.274141  349.025160  375.92  0.3949168  0.4297208
# 2012   88.558259  640.542938  110.204871  231.14  0.1330743  0.6595288
#
#              SF        TSF  DOM  SFD
# 2005  0.4908425  0.4395604  123  148
# 2006  0.4848485  0.2424242   86  137
# 2007  0.7019608  0.2431373  117  154
# 2008  0.8324022  0.5418994  109  154
# 2009  0.5734767  0.4767025  109  145
# 2010  0.5102041  0.5387755   98  153
# 2011   0.529595  0.4610592  142  164
# 2012  0.4198473  0.3473282   64  137
#
# [8 rows x 17 columns]

# %%
plt.plot(SWE.DOM, SWE.ER, 'ok', markersize = 15)
plt.title('Day of Year of Peak SWE vs ET', fontsize = 22)
plt.xlabel('Day of Melt [DOY]', fontsize = 16)
plt.ylabel('Normalized ET [1]', fontsize = 16)

slope, intercept, r_value, p_value, std_err = stats.linregress(SWE.DOM,SWE.ER)
yvals = linpred(slope,intercept,SWE.DOM)
plt.plot(SWE.DOM, yvals, 'r-')

# %% [markdown]
# This suggests that years with late peaks have less growing season ET while years with early peaks have less growing season ET. Of course, years with early peaks have longer growing seasons than years with later peaks...

# %%
print p_value
# Out:
# 0.215718481812

# %%
SWE
# Out:
#      peakswe peakswedate snowfreedate   ablrate       P ablseas          ET  \
# 2005  340.36  2005-05-03   2005-05-28   13.6144  693.42      25  336.624637
# 2006  325.12  2006-03-27   2006-05-17  6.374902  670.56      51  380.840216
# 2007  454.66  2007-04-27   2007-06-03  12.28811   647.7      37  367.622453
# 2008  378.46  2008-04-18   2008-06-02  8.410222  454.66      45  377.225606
# 2009   406.4  2009-04-19   2009-05-25  11.28889  708.66      36  374.337247
# 2010   317.5  2010-04-08   2010-06-02  5.772727   622.3      55  387.884327
# 2011   431.8  2011-05-22   2011-06-13  19.62727  815.34      22  350.368581
# 2012   279.4  2012-03-04   2012-05-16  3.827397  665.48      73  438.903213
#
#                Q       wy_et        wy_q    snow         RR         ER  \
# 2005  194.473687  544.449574  203.455735  304.80  0.2804558  0.4854556
# 2006  153.831705  618.061701  162.206223  162.56  0.2294078  0.5679435
# 2007  193.602895  630.939326  204.428112  157.48  0.2989083  0.5675814
# 2008  133.787896  641.237630  143.944948  246.38  0.2942592  0.8296873
# 2009  183.481086  609.334106  191.483572  337.82  0.2589127  0.5282325
# 2010  214.310640  592.750001  228.596024  335.28  0.3443848  0.6233076
# 2011  321.991496  648.274141  349.025160  375.92  0.3949168  0.4297208
# 2012   88.558259  640.542938  110.204871  231.14  0.1330743  0.6595288
#
#              SF        TSF  DOM  SFD
# 2005  0.4908425  0.4395604  123  148
# 2006  0.4848485  0.2424242   86  137
# 2007  0.7019608  0.2431373  117  154
# 2008  0.8324022  0.5418994  109  154
# 2009  0.5734767  0.4767025  109  145
# 2010  0.5102041  0.5387755   98  153
# 2011   0.529595  0.4610592  142  164
# 2012  0.4198473  0.3473282   64  137
#
# [8 rows x 17 columns]

# %% [markdown]
# ### Plot ablation season vs evaporative fraction

# %%
plt.plot(SWE.ablseas, SWE.ER, 'ok', markersize = 15)
plt.title('Ablation Season Length vs ET', fontsize = 22)
plt.xlabel('Ablation Season Length [Days]', fontsize = 16)
plt.ylabel('Normalized ET [1]', fontsize = 16)

slope, intercept, r_value, p_value, std_err = stats.linregress(SWE.ablseas,SWE.ER)
yvals = linpred(slope, intercept, SWE.ablseas)
plt.plot(SWE.ablseas, yvals, 'r-')

# %%
print p_value
# Out:
# 0.115685320568

# %% [markdown]
# This suggests that longer ablation seasons partition more snowmelt into ET than short

# %% [markdown]
# ### Ablation slope vs evaporative fraction

# %%
plt.plot(SWE.ablrate, SWE.ER, 'ok', markersize = 15)
plt.title('ablation slope vs ET', fontsize = 22)
plt.xlabel('SWE Ablation Rate [mm/day]', fontsize = 16)
plt.ylabel('Normalized ET [1]', fontsize = 16)

slope, intercept, r_value, p_value, std_err = stats.linregress(SWE.ablrate,SWE.ER)
yvals = linpred(slope, intercept, SWE.ablrate)
plt.plot(SWE.ablrate, yvals, 'r-')

# %%
print p_value
# Out:
# 0.072119676421

# %% [markdown]
# ### Plot Water Balace Closure

# %%
plt.plot(SWE.P,SWE.wy_et+SWE.wy_q, 'ok', markersize = 15)
plt.xlabel('Precipitation',fontsize = 16)
plt.ylabel('ET + Q',fontsize = 16)
plt.title('Como Creek Water Balance Closure',fontsize = 22)
plt.axis('equal')

x = np.arange(0,900)
plt.plot(x,x,'r-')

plt.plot(x,x*1.1,'r-')
plt.plot(x,x*1.2,'r-')
plt.plot(x,x*1.3,'r-')
plt.plot(x,x*1.4,'r-')
plt.plot(x,x*1.5,'r-')

# %%
slope, intercept, r_value, p_value, std_err = stats.linregress(SWE.P,SWE.wy_et+SWE.wy_q,)
print slope
# Out:
# 0.423812217134

# %% [markdown]
# Looks like there is some over-closure of the water balance

# %% [markdown]
# ### Plot Snow free date vs ET

# %%
plt.plot(SWE.SFD, SWE.ER, 'ok', markersize = 15)
plt.title('Snow Free Date vs ET', fontsize = 22)
plt.ylabel('Normalized ET [1]', fontsize = 16)
plt.xlabel('Snow Free Date [DOY]', fontsize = 16)

# %% [markdown]
# Not much of a relationship here.
