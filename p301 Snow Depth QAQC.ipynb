# %%
import pandas as pd
import numpy as np
import glob
import matplotlib.pyplot as plt
# %matplotlib inline

pylab.rcParams['figure.figsize'] = (22.0, 11.0)

# %%
upper = pd.read_pickle('./snow_depth/upper_wy2008-2012_ave.pcl')

# %%
plt.plot(upper.index, upper);

# %% [markdown]
# WY 2010 looks like it needs some cleaning at the end.

# %%
strt = '2010-06-01'
nd = '2010-10-15'

plt.plot(upper[strt:nd].index,upper[strt:nd])

# %%
upper['2010-06-12':'2010-09-30']=0.0
upper['2010-06-08':'2010-06-11']=np.NaN

# %%
strt = '2010-06-01'
nd = '2010-10-15'

plt.plot(upper[strt:nd].index,upper[strt:nd])

# %%
upper=upper.interpolate()

# %%
strt = '2010-06-01'
nd = '2010-10-15'

plt.plot(upper[strt:nd].index,upper[strt:nd])

# %%
plt.plot(upper.index, upper);

# %% [markdown]
# Looks Good!

# %%
upper.to_pickle('./snow_depth/upper_wy2008-2012_ave_clean.pcl')
